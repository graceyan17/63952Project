# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
# Load data
df = pd.read_csv("../datasets/joined_complete_info.csv")
df = df.drop_duplicates(subset=['join_title', 'book_desc'], keep='first')
print('columns', df.columns)

df = df[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication',
         'Publisher', 'book_desc', 'book_edition', 'book_format', 'book_pages', 
         'book_rating_count', 'genres', 'book_price', 'language_code', 'join_title']]

df.set_index('join_title', inplace=True)

print(df['book_desc'].head(10))
print("NAs:", df['book_desc'].isna().sum()) # drop? 
print("Empty rows:", (df['book_desc'].str.strip() == "").sum())

df.to_csv('../datasets/book_info_with_tfidf.csv', index=True)
# Out:
# columns Index(['User-ID', 'ISBN', 'Book-Rating', 'User_Location', 'User_Age',
#        'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'join_title', 'book_desc', 'book_edition', 'book_format', 'book_pages',
#        'book_rating', 'book_rating_count', 'book_review_count', 'genres',
#        'book_price', 'language_code'],
#       dtype='object')
# join_title
# a painted house                                    Until that September of 1952, Luke Chandler ha...
# lightning                                           "A gripping novel" from the #1 New York Times...
# the dark half                                      Thad Beaumont would like to say he is innocent...
# anna karenina                                      Acclaimed by many as the world's greatest nove...
# the picture of dorian gray                         ﻿Written in his distinctively dazzling manner,...
# alaska                                             In this sweeping epic of the northernmost Amer...
# the wonderful story of henry sugar and six more    Seven stories of fantasy and fun by the fantas...
# shadowland                                         Ever and Damen have gone through countless liv...
# how to win friends and influence people            You can go after the job you want...and get it...
# the jester                                         Freedom - in eleventh-century France, it is a ...
# Name: book_desc, dtype: object
# NAs: 12
# Empty rows: 0

# %%
desc_col = "book_desc" 
df[desc_col] = df[desc_col].fillna("")

# Fit TF-IDF on ALL descriptions
vectorizer = TfidfVectorizer(
    max_features=8000,
    stop_words="english",
    ngram_range=(1, 1),
)

tfidf_matrix = vectorizer.fit_transform(df[desc_col])

df["TFIDF_Embeddings_Vocab_8000"] = [
    tfidf_matrix[i].toarray().flatten()
    for i in range(tfidf_matrix.shape[0])
]

for i in range(10):
    print(tfidf_matrix[i].count_nonzero())
# Out:
# 57
# 34
# 27
# 58
# 52
# 95
# 42
# 67
# 50
# 50

# %%
unmasked_df = pd.read_csv("../datasets/train_edges.csv")

user_books = unmasked_df.groupby('User-ID').apply(
    lambda x: list(zip(x['join_title'], x['Book-Rating']))
).to_dict()
# Out:
# /var/folders/ql/h0l8mjs14gv_0kjh08fwzy340000gn/T/ipykernel_17430/2562745222.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   user_books = unmasked_df.groupby('User-ID').apply(

# %%
user_to_embed = {}
for user_id, books_ratings in user_books.items():

    high_rated_unmasked = [(join_title, rating) for join_title, rating in books_ratings if rating > 7]

    if len(high_rated_unmasked) == 0:
        continue

    print(f"User {user_id} has rated {len(high_rated_unmasked)} books highly.")

    unmasked_indices = [df.index.get_loc(join_title) for join_title, _ in high_rated_unmasked]
    user_embedding = tfidf_matrix[unmasked_indices].mean(axis=0)
    user_to_embed[user_id] = np.asarray(user_embedding).flatten()

user_embeddings_df = pd.DataFrame.from_dict(
    user_to_embed, 
    orient='index'
)
user_embeddings_df.index.name = 'User-ID'
user_embeddings_df.to_csv('../datasets/user_tfidf_embeddings.csv', index=True)
# Out:
# User 26 has rated 1 books highly.
# User 51 has rated 1 books highly.
# User 53 has rated 1 books highly.
# User 91 has rated 1 books highly.
# User 114 has rated 1 books highly.
# User 183 has rated 1 books highly.
# User 185 has rated 1 books highly.
# User 242 has rated 1 books highly.
# User 243 has rated 1 books highly.
# User 244 has rated 2 books highly.
# User 254 has rated 5 books highly.
# User 256 has rated 1 books highly.
# User 387 has rated 1 books highly.
# User 388 has rated 1 books highly.
# User 413 has rated 1 books highly.
# User 493 has rated 1 books highly.
# User 500 has rated 1 books highly.
# User 507 has rated 1 books highly.
# User 595 has rated 1 books highly.
# User 638 has rated 6 books highly.
# User 651 has rated 1 books highly.
# User 685 has rated 1 books highly.
# User 735 has rated 1 books highly.
# User 746 has rated 1 books highly.
# User 763 has rated 1 books highly.
# User 769 has rated 1 books highly.
# User 777 has rated 1 books highly.
# User 805 has rated 4 books highly.
# User 828 has rated 1 books highly.
# User 882 has rated 5 books highly.
# User 903 has rated 1 books highly.
# User 929 has rated 1 books highly.
# User 965 has rated 1 books highly.
# User 1022 has rated 1 books highly.
# User 1025 has rated 1 books highly.
# User 1032 has rated 1 books highly.
# User 1060 has rated 1 books highly.
# User 1075 has rated 1 books highly.
# User 1083 has rated 1 books highly.
# User 1111 has rated 1 books highly.
# User 1131 has rated 1 books highly.
# User 1155 has rated 1 books highly.
# User 1167 has rated 1 books highly.
# User 1210 has rated 1 books highly.
# User 1211 has rated 1 books highly.
# User 1235 has rated 1 books highly.
# User 1249 has rated 1 books highly.
# User 1252 has rated 1 books highly.
# User 1266 has rated 1 books highly.
# User 1293 has rated 1 books highly.
# User 1330 has rated 1 books highly.
# User 1377 has rated 1 books highly.
# User 1396 has rated 1 books highly.
# User 1409 has rated 1 books highly.
# User 1412 has rated 1 books highly.
# User 1424 has rated 2 books highly.
# User 1434 has rated 1 books highly.
# User 1435 has rated 1 books highly.
# User 1504 has rated 1 books highly.
# User 1530 has rated 1 books highly.
# User 1535 has rated 1 books highly.
# User 1548 has rated 1 books highly.
# User 1570 has rated 1 books highly.
# User 1585 has rated 1 books highly.
# User 1617 has rated 1 books highly.
# User 1619 has rated 1 books highly.
# User 1650 has rated 1 books highly.
# User 1674 has rated 1 books highly.
# User 1706 has rated 1 books highly.
# User 1773 has rated 1 books highly.
# User 1803 has rated 1 books highly.
# User 1848 has rated 2 books highly.
# User 1903 has rated 1 books highly.
# User 1928 has rated 1 books highly.
# User 1945 has rated 1 books highly.
# User 2030 has rated 2 books highly.
# User 2033 has rated 2 books highly.
# User 2041 has rated 1 books highly.
# User 2070 has rated 1 books highly.
# User 2097 has rated 1 books highly.
# User 2099 has rated 1 books highly.
# User 2103 has rated 1 books highly.
# User 2110 has rated 2 books highly.
# User 2179 has rated 1 books highly.
# User 2198 has rated 1 books highly.
# User 2218 has rated 1 books highly.
# User 2238 has rated 1 books highly.
# User 2250 has rated 1 books highly.
# User 2255 has rated 1 books highly.
# User 2271 has rated 1 books highly.
# User 2276 has rated 3 books highly.
# User 2337 has rated 2 books highly.
# User 2357 has rated 1 books highly.
# User 2366 has rated 1 books highly.
# User 2439 has rated 1 books highly.
# User 2442 has rated 1 books highly.
# User 2481 has rated 1 books highly.
# User 2550 has rated 1 books highly.
# User 2591 has rated 1 books highly.
# User 2632 has rated 1 books highly.
# User 2718 has rated 1 books highly.
# User 2719 has rated 1 books highly.
# User 2749 has rated 1 books highly.
# User 2766 has rated 5 books highly.
# User 2789 has rated 1 books highly.
# User 2799 has rated 1 books highly.
# User 2853 has rated 1 books highly.
# User 2861 has rated 1 books highly.
# User 2891 has rated 1 books highly.
# User 2996 has rated 1 books highly.
# User 3026 has rated 1 books highly.
# User 3048 has rated 1 books highly.
# User 3104 has rated 1 books highly.
# User 3145 has rated 2 books highly.
# User 3167 has rated 3 books highly.
# User 3172 has rated 1 books highly.
# User 3282 has rated 1 books highly.
# User 3329 has rated 1 books highly.
# User 3331 has rated 1 books highly.
# User 3346 has rated 1 books highly.
# User 3350 has rated 1 books highly.
# User 3363 has rated 1 books highly.
# User 3416 has rated 1 books highly.
# User 3462 has rated 1 books highly.
# User 3471 has rated 1 books highly.
# User 3472 has rated 1 books highly.
# User 3481 has rated 1 books highly.
# User 3507 has rated 1 books highly.
# User 3512 has rated 1 books highly.
# User 3538 has rated 1 books highly.
# User 3541 has rated 1 books highly.
# User 3542 has rated 1 books highly.
# User 3543 has rated 1 books highly.
# User 3556 has rated 1 books highly.
# User 3578 has rated 2 books highly.
# User 3596 has rated 1 books highly.
# User 3605 has rated 1 books highly.
# User 3628 has rated 1 books highly.
# User 3632 has rated 1 books highly.
# User 3669 has rated 1 books highly.
# User 3675 has rated 1 books highly.
# User 3694 has rated 1 books highly.
# User 3719 has rated 1 books highly.
# User 3761 has rated 1 books highly.
# User 3799 has rated 1 books highly.
# User 3817 has rated 2 books highly.
# User 3827 has rated 1 books highly.
# User 3837 has rated 1 books highly.
# User 3840 has rated 1 books highly.
# User 3999 has rated 1 books highly.
# User 4017 has rated 10 books highly.
# User 4077 has rated 1 books highly.
# User 4091 has rated 1 books highly.
# User 4092 has rated 1 books highly.
# User 4138 has rated 1 books highly.
# User 4169 has rated 1 books highly.
# User 4188 has rated 1 books highly.
# User 4221 has rated 1 books highly.
# User 4260 has rated 1 books highly.
# User 4334 has rated 1 books highly.
# User 4365 has rated 1 books highly.
# User 4385 has rated 2 books highly.
# User 4431 has rated 1 books highly.
# User 4483 has rated 1 books highly.
# User 4541 has rated 1 books highly.
# User 4551 has rated 1 books highly.
# User 4599 has rated 1 books highly.
# User 4732 has rated 1 books highly.
# User 4766 has rated 1 books highly.
# User 4795 has rated 1 books highly.
# User 4870 has rated 1 books highly.
# User 5037 has rated 1 books highly.
# User 5091 has rated 1 books highly.
# User 5183 has rated 1 books highly.
# User 5207 has rated 1 books highly.
# User 5209 has rated 1 books highly.
# User 5268 has rated 1 books highly.
# User 5273 has rated 1 books highly.
# User 5333 has rated 1 books highly.
# User 5361 has rated 1 books highly.
# User 5385 has rated 1 books highly.
# User 5439 has rated 2 books highly.
# User 5443 has rated 1 books highly.
# User 5448 has rated 1 books highly.
# User 5476 has rated 1 books highly.
# User 5499 has rated 1 books highly.
# User 5539 has rated 2 books highly.
# User 5543 has rated 1 books highly.
# User 5553 has rated 1 books highly.
# User 5559 has rated 1 books highly.
# User 5582 has rated 10 books highly.
# User 5599 has rated 1 books highly.
# User 5638 has rated 1 books highly.
# User 5703 has rated 1 books highly.
# User 5728 has rated 1 books highly.
# User 5737 has rated 1 books highly.
# User 5741 has rated 1 books highly.
# User 5783 has rated 1 books highly.
# User 5861 has rated 1 books highly.
# User 5882 has rated 1 books highly.
# User 5912 has rated 1 books highly.
# User 5922 has rated 1 books highly.
# User 6017 has rated 1 books highly.
# User 6022 has rated 1 books highly.
# User 6073 has rated 4 books highly.
# User 6102 has rated 1 books highly.
# User 6112 has rated 1 books highly.
# User 6115 has rated 2 books highly.
# User 6125 has rated 1 books highly.
# User 6238 has rated 4 books highly.
# User 6247 has rated 1 books highly.
# User 6251 has rated 8 books highly.
# User 6263 has rated 1 books highly.
# User 6280 has rated 1 books highly.
# User 6308 has rated 1 books highly.
# User 6323 has rated 1 books highly.
# User 6348 has rated 1 books highly.
# User 6364 has rated 1 books highly.
# User 6376 has rated 1 books highly.
# User 6392 has rated 1 books highly.
# User 6415 has rated 1 books highly.
# User 6450 has rated 1 books highly.
# User 6532 has rated 2 books highly.
# User 6535 has rated 1 books highly.
# User 6543 has rated 3 books highly.
# User 6563 has rated 4 books highly.
# User 6575 has rated 8 books highly.
# User 6577 has rated 2 books highly.
# User 6604 has rated 1 books highly.
# User 6611 has rated 2 books highly.
# User 6637 has rated 1 books highly.
# User 6679 has rated 1 books highly.
# User 6680 has rated 1 books highly.
# User 6682 has rated 1 books highly.
# User 6689 has rated 1 books highly.
# User 6704 has rated 1 books highly.
# User 6764 has rated 1 books highly.
# User 6768 has rated 1 books highly.
# User 6781 has rated 1 books highly.
# User 6787 has rated 1 books highly.
# User 6789 has rated 1 books highly.
# User 6803 has rated 1 books highly.
# User 6815 has rated 1 books highly.
# User 6884 has rated 1 books highly.
# User 6893 has rated 1 books highly.
# User 6894 has rated 1 books highly.
# User 6900 has rated 1 books highly.
# User 6912 has rated 1 books highly.
# User 6941 has rated 1 books highly.
# User 6958 has rated 1 books highly.
# User 6975 has rated 1 books highly.
# User 7035 has rated 1 books highly.
# User 7071 has rated 1 books highly.
# User 7079 has rated 1 books highly.
# User 7084 has rated 1 books highly.
# User 7105 has rated 1 books highly.
# User 7119 has rated 1 books highly.
# User 7125 has rated 2 books highly.
# User 7155 has rated 1 books highly.
# User 7158 has rated 4 books highly.
# User 7160 has rated 1 books highly.
# User 7194 has rated 1 books highly.
# User 7210 has rated 4 books highly.
# User 7226 has rated 1 books highly.
# User 7248 has rated 1 books highly.
# User 7283 has rated 3 books highly.
# User 7286 has rated 1 books highly.
# User 7316 has rated 1 books highly.
# User 7319 has rated 1 books highly.
# User 7346 has rated 16 books highly.
# User 7384 has rated 1 books highly.
# User 7409 has rated 1 books highly.
# User 7412 has rated 1 books highly.
# User 7509 has rated 2 books highly.
# User 7528 has rated 1 books highly.
# User 7557 has rated 1 books highly.
# User 7569 has rated 1 books highly.
# User 7576 has rated 1 books highly.
# User 7620 has rated 2 books highly.
# User 7680 has rated 1 books highly.
# User 7809 has rated 1 books highly.
# User 7825 has rated 1 books highly.
# User 7841 has rated 3 books highly.
# User 7856 has rated 1 books highly.
# User 7860 has rated 1 books highly.
# User 7874 has rated 1 books highly.
# User 7887 has rated 1 books highly.
# User 7915 has rated 2 books highly.
# User 7930 has rated 1 books highly.
# User 7945 has rated 1 books highly.
# User 7958 has rated 4 books highly.
# User 8006 has rated 1 books highly.
# User 8019 has rated 3 books highly.
# User 8054 has rated 1 books highly.
# User 8066 has rated 1 books highly.
# User 8067 has rated 1 books highly.
# User 8115 has rated 1 books highly.
# User 8154 has rated 1 books highly.
# User 8167 has rated 1 books highly.
# User 8186 has rated 1 books highly.
# User 8187 has rated 1 books highly.
# User 8188 has rated 1 books highly.
# User 8240 has rated 1 books highly.
# User 8245 has rated 12 books highly.
# User 8253 has rated 9 books highly.
# User 8255 has rated 2 books highly.
# User 8282 has rated 1 books highly.
# User 8290 has rated 1 books highly.
# User 8296 has rated 1 books highly.
# User 8309 has rated 1 books highly.
# User 8362 has rated 1 books highly.
# User 8370 has rated 1 books highly.
# User 8454 has rated 5 books highly.
# User 8473 has rated 1 books highly.
# User 8570 has rated 1 books highly.
# User 8652 has rated 1 books highly.
# User 8681 has rated 5 books highly.
# User 8734 has rated 1 books highly.
# User 8747 has rated 1 books highly.
# User 8782 has rated 2 books highly.
# User 8801 has rated 2 books highly.
# User 8843 has rated 1 books highly.
# User 8870 has rated 1 books highly.
# User 8872 has rated 1 books highly.
# User 8890 has rated 1 books highly.
# User 8935 has rated 1 books highly.
# User 8936 has rated 1 books highly.
# User 8937 has rated 1 books highly.
# User 9030 has rated 1 books highly.
# User 9138 has rated 1 books highly.
# User 9139 has rated 1 books highly.
# User 9177 has rated 1 books highly.
# User 9227 has rated 1 books highly.
# User 9272 has rated 1 books highly.
# User 9296 has rated 1 books highly.
# User 9340 has rated 1 books highly.
# User 9343 has rated 1 books highly.
# User 9354 has rated 2 books highly.
# User 9389 has rated 1 books highly.
# User 9454 has rated 1 books highly.
# User 9502 has rated 1 books highly.
# User 9504 has rated 1 books highly.
# User 9540 has rated 1 books highly.
# User 9568 has rated 1 books highly.
# User 9574 has rated 1 books highly.
# User 9703 has rated 1 books highly.
# User 9718 has rated 1 books highly.
# User 9721 has rated 1 books highly.
# User 9728 has rated 1 books highly.
# User 9747 has rated 2 books highly.
# User 9773 has rated 1 books highly.
# User 9856 has rated 2 books highly.
# User 9884 has rated 1 books highly.
# User 9915 has rated 1 books highly.
# User 9952 has rated 1 books highly.
# User 10003 has rated 1 books highly.
# User 10030 has rated 1 books highly.
# User 10047 has rated 1 books highly.
# User 10063 has rated 1 books highly.
# User 10090 has rated 1 books highly.
# User 10118 has rated 3 books highly.
# User 10124 has rated 1 books highly.
# User 10164 has rated 1 books highly.
# User 10199 has rated 2 books highly.
# User 10284 has rated 1 books highly.
# User 10314 has rated 2 books highly.
# User 10329 has rated 1 books highly.
# User 10354 has rated 3 books highly.
# User 10447 has rated 3 books highly.
# User 10560 has rated 2 books highly.
# User 10596 has rated 1 books highly.
# User 10601 has rated 1 books highly.
# User 10607 has rated 1 books highly.
# User 10627 has rated 1 books highly.
# User 10630 has rated 1 books highly.
# User 10660 has rated 1 books highly.
# User 10819 has rated 2 books highly.
# User 10829 has rated 1 books highly.
# User 10830 has rated 1 books highly.
# User 10836 has rated 1 books highly.
# User 10852 has rated 1 books highly.
# User 10921 has rated 1 books highly.
# User 10949 has rated 2 books highly.
# User 10951 has rated 1 books highly.
# User 10965 has rated 1 books highly.
# User 11031 has rated 1 books highly.
# User 11120 has rated 1 books highly.
# User 11179 has rated 1 books highly.
# User 11224 has rated 1 books highly.
# User 11245 has rated 1 books highly.
# User 11287 has rated 1 books highly.
# User 11317 has rated 1 books highly.
# User 11325 has rated 2 books highly.
# User 11349 has rated 1 books highly.
# User 11362 has rated 1 books highly.
# User 11400 has rated 2 books highly.
# User 11403 has rated 1 books highly.
# User 11451 has rated 1 books highly.
# User 11453 has rated 1 books highly.
# User 11474 has rated 1 books highly.
# User 11489 has rated 1 books highly.
# User 11497 has rated 1 books highly.
# User 11507 has rated 1 books highly.
# User 11517 has rated 1 books highly.
# User 11584 has rated 1 books highly.
# User 11601 has rated 5 books highly.
# User 11629 has rated 1 books highly.
# User 11638 has rated 2 books highly.
# User 11676 has rated 134 books highly.
# User 11690 has rated 1 books highly.
# User 11709 has rated 1 books highly.
# User 11718 has rated 2 books highly.
# User 11788 has rated 1 books highly.
# User 11832 has rated 1 books highly.
# User 11916 has rated 1 books highly.
# User 11944 has rated 1 books highly.
# User 11993 has rated 1 books highly.
# User 12014 has rated 1 books highly.
# User 12081 has rated 1 books highly.
# User 12097 has rated 1 books highly.
# User 12100 has rated 1 books highly.
# User 12137 has rated 1 books highly.
# User 12138 has rated 1 books highly.
# User 12189 has rated 1 books highly.
# User 12209 has rated 1 books highly.
# User 12233 has rated 1 books highly.
# User 12272 has rated 2 books highly.
# User 12285 has rated 1 books highly.
# User 12315 has rated 1 books highly.
# User 12484 has rated 1 books highly.
# User 12538 has rated 2 books highly.
# User 12569 has rated 2 books highly.
# User 12570 has rated 1 books highly.
# User 12619 has rated 1 books highly.
# User 12630 has rated 1 books highly.
# User 12671 has rated 1 books highly.
# User 12685 has rated 1 books highly.
# User 12698 has rated 1 books highly.
# User 12707 has rated 2 books highly.
# User 12710 has rated 1 books highly.
# User 12784 has rated 1 books highly.
# User 12817 has rated 1 books highly.
# User 12824 has rated 2 books highly.
# User 12863 has rated 1 books highly.
# User 12866 has rated 1 books highly.
# User 12917 has rated 2 books highly.
# User 12923 has rated 1 books highly.
# User 12951 has rated 1 books highly.
# User 12963 has rated 1 books highly.
# User 12966 has rated 1 books highly.
# User 12982 has rated 7 books highly.
# User 13039 has rated 1 books highly.
# User 13080 has rated 1 books highly.
# User 13082 has rated 1 books highly.
# User 13133 has rated 1 books highly.
# User 13164 has rated 1 books highly.
# User 13173 has rated 1 books highly.
# User 13221 has rated 1 books highly.
# User 13231 has rated 1 books highly.
# User 13252 has rated 1 books highly.
# User 13273 has rated 2 books highly.
# User 13279 has rated 1 books highly.
# User 13280 has rated 1 books highly.
# User 13339 has rated 1 books highly.
# User 13428 has rated 1 books highly.
# User 13551 has rated 2 books highly.
# User 13552 has rated 5 books highly.
# User 13582 has rated 3 books highly.
# User 13603 has rated 1 books highly.
# User 13642 has rated 1 books highly.
# User 13666 has rated 1 books highly.
# User 13685 has rated 1 books highly.
# User 13709 has rated 1 books highly.
# User 13735 has rated 1 books highly.
# User 13794 has rated 1 books highly.
# User 13850 has rated 6 books highly.
# User 14079 has rated 2 books highly.
# User 14084 has rated 1 books highly.
# User 14116 has rated 1 books highly.
# User 14143 has rated 1 books highly.
# User 14183 has rated 1 books highly.
# User 14232 has rated 1 books highly.
# User 14254 has rated 1 books highly.
# User 14281 has rated 1 books highly.
# User 14319 has rated 2 books highly.
# User 14357 has rated 1 books highly.
# User 14369 has rated 1 books highly.
# User 14374 has rated 2 books highly.
# User 14387 has rated 3 books highly.
# User 14392 has rated 1 books highly.
# User 14417 has rated 1 books highly.
# User 14418 has rated 1 books highly.
# User 14422 has rated 4 books highly.
# User 14423 has rated 1 books highly.
# User 14456 has rated 4 books highly.
# User 14461 has rated 2 books highly.
# User 14517 has rated 1 books highly.
# User 14521 has rated 1 books highly.
# User 14546 has rated 1 books highly.
# User 14598 has rated 1 books highly.
# User 14641 has rated 1 books highly.
# User 14667 has rated 2 books highly.
# User 14681 has rated 1 books highly.
# User 14698 has rated 1 books highly.
# User 14710 has rated 1 books highly.
# User 14744 has rated 3 books highly.
# User 14783 has rated 1 books highly.
# User 14789 has rated 1 books highly.
# User 14791 has rated 1 books highly.
# User 14812 has rated 1 books highly.
# User 14965 has rated 1 books highly.
# User 15040 has rated 1 books highly.
# User 15049 has rated 1 books highly.
# User 15145 has rated 1 books highly.
# User 15179 has rated 1 books highly.
# User 15184 has rated 1 books highly.
# User 15230 has rated 1 books highly.
# User 15351 has rated 1 books highly.
# User 15355 has rated 1 books highly.
# User 15367 has rated 1 books highly.
# User 15408 has rated 2 books highly.
# User 15418 has rated 2 books highly.
# User 15496 has rated 1 books highly.
# User 15510 has rated 1 books highly.
# User 15527 has rated 1 books highly.
# User 15571 has rated 1 books highly.
# User 15580 has rated 1 books highly.
# User 15583 has rated 1 books highly.
# User 15589 has rated 1 books highly.
# User 15602 has rated 3 books highly.
# User 15623 has rated 1 books highly.
# User 15651 has rated 1 books highly.
# User 15654 has rated 1 books highly.
# User 15655 has rated 1 books highly.
# User 15670 has rated 1 books highly.
# User 15692 has rated 1 books highly.
# User 15700 has rated 1 books highly.
# User 15720 has rated 1 books highly.
# User 15759 has rated 1 books highly.
# User 15775 has rated 1 books highly.
# User 15780 has rated 1 books highly.
# User 15812 has rated 1 books highly.
# User 15819 has rated 1 books highly.
# User 15845 has rated 1 books highly.
# User 15890 has rated 1 books highly.
# User 15945 has rated 3 books highly.
# User 16009 has rated 2 books highly.
# User 16036 has rated 1 books highly.
# User 16047 has rated 1 books highly.
# User 16106 has rated 5 books highly.
# User 16129 has rated 1 books highly.
# User 16161 has rated 1 books highly.
# User 16226 has rated 1 books highly.
# User 16231 has rated 1 books highly.
# User 16241 has rated 1 books highly.
# User 16244 has rated 1 books highly.
# User 16246 has rated 2 books highly.
# User 16263 has rated 1 books highly.
# User 16266 has rated 1 books highly.
# User 16319 has rated 1 books highly.
# User 16338 has rated 1 books highly.
# User 16417 has rated 1 books highly.
# User 16425 has rated 1 books highly.
# User 16459 has rated 1 books highly.
# User 16488 has rated 3 books highly.
# User 16504 has rated 2 books highly.
# User 16509 has rated 1 books highly.
# User 16545 has rated 1 books highly.
# User 16599 has rated 1 books highly.
# User 16634 has rated 12 books highly.
# User 16643 has rated 1 books highly.
# User 16659 has rated 1 books highly.
# User 16661 has rated 1 books highly.
# User 16687 has rated 1 books highly.
# User 16711 has rated 1 books highly.
# User 16717 has rated 1 books highly.
# User 16718 has rated 2 books highly.
# User 16736 has rated 1 books highly.
# User 16746 has rated 1 books highly.
# User 16755 has rated 1 books highly.
# User 16781 has rated 2 books highly.
# User 16795 has rated 24 books highly.
# User 16803 has rated 1 books highly.
# User 16805 has rated 1 books highly.
# User 16827 has rated 1 books highly.
# User 16867 has rated 1 books highly.
# User 16877 has rated 2 books highly.
# User 16916 has rated 2 books highly.
# User 16935 has rated 1 books highly.
# User 16943 has rated 1 books highly.
# User 16989 has rated 1 books highly.
# User 16996 has rated 2 books highly.
# User 16999 has rated 1 books highly.
# User 17000 has rated 1 books highly.
# User 17003 has rated 5 books highly.
# User 17058 has rated 1 books highly.
# User 17073 has rated 1 books highly.
# User 17108 has rated 1 books highly.
# User 17122 has rated 1 books highly.
# User 17159 has rated 2 books highly.
# User 17180 has rated 1 books highly.
# User 17190 has rated 1 books highly.
# User 17233 has rated 1 books highly.
# User 17277 has rated 1 books highly.
# User 17337 has rated 1 books highly.
# User 17402 has rated 1 books highly.
# User 17461 has rated 1 books highly.
# User 17542 has rated 1 books highly.
# User 17588 has rated 1 books highly.
# User 17661 has rated 1 books highly.
# User 17667 has rated 1 books highly.
# User 17721 has rated 1 books highly.
# User 17752 has rated 1 books highly.
# User 17792 has rated 1 books highly.
# User 17892 has rated 1 books highly.
# User 17894 has rated 2 books highly.
# User 17906 has rated 2 books highly.
# User 17917 has rated 1 books highly.
# User 17935 has rated 1 books highly.
# User 17950 has rated 4 books highly.
# User 17965 has rated 1 books highly.
# User 17970 has rated 1 books highly.
# User 17976 has rated 1 books highly.
# User 18082 has rated 1 books highly.
# User 18155 has rated 1 books highly.
# User 18167 has rated 2 books highly.
# User 18176 has rated 1 books highly.
# User 18203 has rated 2 books highly.
# User 18216 has rated 1 books highly.
# User 18254 has rated 1 books highly.
# User 18311 has rated 1 books highly.
# User 18312 has rated 1 books highly.
# User 18317 has rated 1 books highly.
# User 18323 has rated 1 books highly.
# User 18401 has rated 1 books highly.
# User 18408 has rated 1 books highly.
# User 18439 has rated 1 books highly.
# User 18440 has rated 1 books highly.
# User 18454 has rated 1 books highly.
# User 18641 has rated 1 books highly.
# User 18713 has rated 1 books highly.
# User 18746 has rated 1 books highly.
# User 18802 has rated 1 books highly.
# User 18850 has rated 1 books highly.
# User 18913 has rated 1 books highly.
# User 19010 has rated 1 books highly.
# User 19011 has rated 1 books highly.
# User 19085 has rated 2 books highly.
# User 19107 has rated 1 books highly.
# User 19127 has rated 1 books highly.
# User 19132 has rated 1 books highly.
# User 19163 has rated 1 books highly.
# User 19221 has rated 1 books highly.
# User 19233 has rated 2 books highly.
# User 19259 has rated 1 books highly.
# User 19336 has rated 1 books highly.
# User 19362 has rated 1 books highly.
# User 19371 has rated 1 books highly.
# User 19440 has rated 1 books highly.
# User 19493 has rated 1 books highly.
# User 19522 has rated 1 books highly.
# User 19529 has rated 1 books highly.
# User 19549 has rated 1 books highly.
# User 19558 has rated 1 books highly.
# User 19565 has rated 1 books highly.
# User 19571 has rated 1 books highly.
# User 19573 has rated 2 books highly.
# User 19605 has rated 1 books highly.
# User 19643 has rated 1 books highly.
# User 19659 has rated 1 books highly.
# User 19664 has rated 2 books highly.
# User 19725 has rated 1 books highly.
# User 19760 has rated 1 books highly.
# User 19838 has rated 1 books highly.
# User 19842 has rated 1 books highly.
# User 19897 has rated 1 books highly.
# User 19967 has rated 1 books highly.
# User 19969 has rated 2 books highly.
# User 20015 has rated 1 books highly.
# User 20029 has rated 1 books highly.
# User 20032 has rated 1 books highly.
# User 20034 has rated 2 books highly.
# User 20060 has rated 3 books highly.
# User 20082 has rated 1 books highly.
# User 20119 has rated 1 books highly.
# User 20120 has rated 1 books highly.
# User 20172 has rated 5 books highly.
# User 20173 has rated 1 books highly.
# User 20180 has rated 4 books highly.
# User 20201 has rated 1 books highly.
# User 20265 has rated 2 books highly.
# User 20347 has rated 1 books highly.
# User 20350 has rated 1 books highly.
# User 20388 has rated 1 books highly.
# User 20462 has rated 2 books highly.
# User 20561 has rated 1 books highly.
# User 20575 has rated 1 books highly.
# User 20605 has rated 1 books highly.
# User 20627 has rated 1 books highly.
# User 20629 has rated 1 books highly.
# User 20729 has rated 1 books highly.
# User 20768 has rated 1 books highly.
# User 20794 has rated 1 books highly.
# User 20813 has rated 1 books highly.
# User 20879 has rated 1 books highly.
# User 20921 has rated 1 books highly.
# User 20961 has rated 1 books highly.
# User 20971 has rated 1 books highly.
# User 20982 has rated 1 books highly.
# User 21014 has rated 8 books highly.
# User 21031 has rated 1 books highly.
# User 21063 has rated 1 books highly.
# User 21076 has rated 1 books highly.
# User 21083 has rated 1 books highly.
# User 21090 has rated 1 books highly.
# User 21102 has rated 1 books highly.
# User 21124 has rated 1 books highly.
# User 21128 has rated 1 books highly.
# User 21187 has rated 1 books highly.
# User 21188 has rated 1 books highly.
# User 21191 has rated 1 books highly.
# User 21202 has rated 1 books highly.
# User 21207 has rated 1 books highly.
# User 21252 has rated 2 books highly.
# User 21257 has rated 1 books highly.
# User 21274 has rated 2 books highly.
# User 21340 has rated 1 books highly.
# User 21348 has rated 1 books highly.
# User 21357 has rated 1 books highly.
# User 21370 has rated 2 books highly.
# User 21391 has rated 1 books highly.
# User 21393 has rated 1 books highly.
# User 21402 has rated 1 books highly.
# User 21404 has rated 2 books highly.
# User 21418 has rated 1 books highly.
# User 21450 has rated 1 books highly.
# User 21462 has rated 1 books highly.
# User 21484 has rated 3 books highly.
# User 21494 has rated 1 books highly.
# User 21533 has rated 1 books highly.
# User 21540 has rated 1 books highly.
# User 21568 has rated 1 books highly.
# User 21576 has rated 5 books highly.
# User 21617 has rated 1 books highly.
# User 21627 has rated 1 books highly.
# User 21659 has rated 3 books highly.
# User 21660 has rated 1 books highly.
# User 21737 has rated 1 books highly.
# User 21777 has rated 1 books highly.
# User 21789 has rated 1 books highly.
# User 21791 has rated 1 books highly.
# User 21861 has rated 1 books highly.
# User 21874 has rated 1 books highly.
# User 21875 has rated 1 books highly.
# User 21888 has rated 1 books highly.
# User 21894 has rated 1 books highly.
# User 21909 has rated 1 books highly.
# User 21937 has rated 1 books highly.
# User 21991 has rated 1 books highly.
# User 22045 has rated 2 books highly.
# User 22047 has rated 1 books highly.
# User 22051 has rated 1 books highly.
# User 22062 has rated 1 books highly.
# User 22074 has rated 3 books highly.
# User 22107 has rated 1 books highly.
# User 22154 has rated 1 books highly.
# User 22162 has rated 1 books highly.
# User 22177 has rated 1 books highly.
# User 22252 has rated 1 books highly.
# User 22338 has rated 1 books highly.
# User 22343 has rated 1 books highly.
# User 22365 has rated 1 books highly.
# User 22396 has rated 1 books highly.
# User 22403 has rated 1 books highly.
# User 22423 has rated 1 books highly.
# User 22439 has rated 1 books highly.
# User 22464 has rated 2 books highly.
# User 22482 has rated 1 books highly.
# User 22511 has rated 1 books highly.
# User 22521 has rated 3 books highly.
# User 22532 has rated 1 books highly.
# User 22617 has rated 1 books highly.
# User 22625 has rated 11 books highly.
# User 22637 has rated 1 books highly.
# User 22650 has rated 1 books highly.
# User 22665 has rated 1 books highly.
# User 22695 has rated 1 books highly.
# User 22713 has rated 1 books highly.
# User 22720 has rated 1 books highly.
# User 22813 has rated 2 books highly.
# User 22822 has rated 1 books highly.
# User 22830 has rated 1 books highly.
# User 22873 has rated 1 books highly.
# User 22912 has rated 1 books highly.
# User 22917 has rated 1 books highly.
# User 22924 has rated 1 books highly.
# User 22936 has rated 2 books highly.
# User 22968 has rated 1 books highly.
# User 22975 has rated 1 books highly.
# User 23020 has rated 3 books highly.
# User 23032 has rated 1 books highly.
# User 23038 has rated 1 books highly.
# User 23065 has rated 2 books highly.
# User 23107 has rated 1 books highly.
# User 23138 has rated 1 books highly.
# User 23185 has rated 1 books highly.
# User 23238 has rated 1 books highly.
# User 23280 has rated 1 books highly.
# User 23353 has rated 1 books highly.
# User 23511 has rated 4 books highly.
# User 23547 has rated 1 books highly.
# User 23571 has rated 6 books highly.
# User 23582 has rated 1 books highly.
# User 23588 has rated 1 books highly.
# User 23619 has rated 1 books highly.
# User 23634 has rated 1 books highly.
# User 23659 has rated 1 books highly.
# User 23664 has rated 1 books highly.
# User 23680 has rated 2 books highly.
# User 23689 has rated 1 books highly.
# User 23699 has rated 3 books highly.
# User 23714 has rated 1 books highly.
# User 23749 has rated 1 books highly.
# User 23768 has rated 7 books highly.
# User 23771 has rated 1 books highly.
# User 23772 has rated 1 books highly.
# User 23784 has rated 1 books highly.
# User 23785 has rated 1 books highly.
# User 23792 has rated 1 books highly.
# User 23799 has rated 1 books highly.
# User 23832 has rated 1 books highly.
# User 23871 has rated 2 books highly.
# User 23872 has rated 8 books highly.
# User 23902 has rated 32 books highly.
# User 23948 has rated 1 books highly.
# User 24025 has rated 1 books highly.
# User 24052 has rated 1 books highly.
# User 24064 has rated 1 books highly.
# User 24082 has rated 1 books highly.
# User 24100 has rated 1 books highly.
# User 24111 has rated 1 books highly.
# User 24186 has rated 1 books highly.
# User 24194 has rated 1 books highly.
# User 24215 has rated 1 books highly.
# User 24220 has rated 1 books highly.
# User 24221 has rated 1 books highly.
# User 24223 has rated 1 books highly.
# User 24256 has rated 1 books highly.
# User 24314 has rated 1 books highly.
# User 24352 has rated 1 books highly.
# User 24394 has rated 1 books highly.
# User 24395 has rated 1 books highly.
# User 24433 has rated 3 books highly.
# User 24576 has rated 1 books highly.
# User 24603 has rated 1 books highly.
# User 24627 has rated 1 books highly.
# User 24685 has rated 1 books highly.
# User 24702 has rated 1 books highly.
# User 24733 has rated 1 books highly.
# User 24768 has rated 1 books highly.
# User 24778 has rated 1 books highly.
# User 24781 has rated 1 books highly.
# User 24835 has rated 1 books highly.
# User 24838 has rated 1 books highly.
# User 24921 has rated 1 books highly.
# User 24933 has rated 2 books highly.
# User 24934 has rated 1 books highly.
# User 24995 has rated 2 books highly.
# User 25012 has rated 1 books highly.
# User 25041 has rated 1 books highly.
# User 25109 has rated 1 books highly.
# User 25124 has rated 1 books highly.
# User 25131 has rated 2 books highly.
# User 25197 has rated 1 books highly.
# User 25216 has rated 3 books highly.
# User 25221 has rated 1 books highly.
# User 25225 has rated 1 books highly.
# User 25253 has rated 1 books highly.
# User 25287 has rated 1 books highly.
# User 25373 has rated 1 books highly.
# User 25394 has rated 1 books highly.
# User 25395 has rated 1 books highly.
# User 25409 has rated 5 books highly.
# User 25410 has rated 2 books highly.
# User 25533 has rated 1 books highly.
# User 25583 has rated 2 books highly.
# User 25601 has rated 1 books highly.
# User 25611 has rated 1 books highly.
# User 25616 has rated 1 books highly.
# User 25656 has rated 1 books highly.
# User 25669 has rated 1 books highly.
# User 25681 has rated 1 books highly.
# User 25706 has rated 1 books highly.
# User 25760 has rated 1 books highly.
# User 25804 has rated 1 books highly.
# User 25822 has rated 1 books highly.
# User 25827 has rated 1 books highly.
# User 25909 has rated 1 books highly.
# User 25916 has rated 1 books highly.
# User 25930 has rated 1 books highly.
# User 25981 has rated 2 books highly.
# User 25996 has rated 1 books highly.
# User 26018 has rated 1 books highly.
# User 26057 has rated 2 books highly.
# User 26072 has rated 1 books highly.
# User 26112 has rated 1 books highly.
# User 26145 has rated 1 books highly.
# User 26146 has rated 1 books highly.
# User 26182 has rated 1 books highly.
# User 26206 has rated 1 books highly.
# User 26249 has rated 1 books highly.
# User 26280 has rated 1 books highly.
# User 26371 has rated 1 books highly.
# User 26374 has rated 1 books highly.
# User 26487 has rated 1 books highly.
# User 26501 has rated 1 books highly.
# User 26521 has rated 1 books highly.
# User 26544 has rated 4 books highly.
# User 26553 has rated 2 books highly.
# User 26561 has rated 1 books highly.
# User 26583 has rated 1 books highly.
# User 26621 has rated 1 books highly.
# User 26624 has rated 1 books highly.
# User 26673 has rated 1 books highly.
# User 26713 has rated 1 books highly.
# User 26756 has rated 1 books highly.
# User 26761 has rated 1 books highly.
# User 26774 has rated 1 books highly.
# User 26782 has rated 1 books highly.
# User 26813 has rated 1 books highly.
# User 26823 has rated 2 books highly.
# User 26883 has rated 1 books highly.
# User 26906 has rated 1 books highly.
# User 27027 has rated 1 books highly.
# User 27061 has rated 1 books highly.
# User 27140 has rated 2 books highly.
# User 27141 has rated 1 books highly.
# User 27161 has rated 1 books highly.
# User 27169 has rated 1 books highly.
# User 27204 has rated 2 books highly.
# User 27265 has rated 1 books highly.
# User 27277 has rated 1 books highly.
# User 27313 has rated 1 books highly.
# User 27317 has rated 1 books highly.
# User 27349 has rated 1 books highly.
# User 27352 has rated 1 books highly.
# User 27462 has rated 1 books highly.
# User 27470 has rated 1 books highly.
# User 27472 has rated 6 books highly.
# User 27538 has rated 1 books highly.
# User 27617 has rated 1 books highly.
# User 27628 has rated 1 books highly.
# User 27647 has rated 2 books highly.
# User 27684 has rated 1 books highly.
# User 27738 has rated 1 books highly.
# User 27740 has rated 1 books highly.
# User 27788 has rated 1 books highly.
# User 27812 has rated 2 books highly.
# User 27826 has rated 1 books highly.
# User 27907 has rated 1 books highly.
# User 27947 has rated 1 books highly.
# User 28016 has rated 2 books highly.
# User 28023 has rated 1 books highly.
# User 28082 has rated 1 books highly.
# User 28091 has rated 1 books highly.
# User 28123 has rated 1 books highly.
# User 28150 has rated 2 books highly.
# User 28156 has rated 1 books highly.
# User 28177 has rated 6 books highly.
# User 28194 has rated 1 books highly.
# User 28195 has rated 1 books highly.
# User 28203 has rated 1 books highly.
# User 28204 has rated 2 books highly.
# User 28216 has rated 1 books highly.
# User 28219 has rated 1 books highly.
# User 28222 has rated 2 books highly.
# User 28234 has rated 1 books highly.
# User 28269 has rated 1 books highly.
# User 28289 has rated 1 books highly.
# User 28299 has rated 1 books highly.
# User 28366 has rated 1 books highly.
# User 28372 has rated 1 books highly.
# User 28373 has rated 1 books highly.
# User 28430 has rated 1 books highly.
# User 28463 has rated 1 books highly.
# User 28477 has rated 1 books highly.
# User 28492 has rated 1 books highly.
# User 28495 has rated 1 books highly.
# User 28523 has rated 1 books highly.
# User 28619 has rated 1 books highly.
# User 28634 has rated 7 books highly.
# User 28647 has rated 1 books highly.
# User 28663 has rated 1 books highly.
# User 28666 has rated 1 books highly.
# User 28680 has rated 1 books highly.
# User 28705 has rated 1 books highly.
# User 28709 has rated 1 books highly.
# User 28718 has rated 1 books highly.
# User 28735 has rated 2 books highly.
# User 28763 has rated 1 books highly.
# User 28775 has rated 1 books highly.
# User 28784 has rated 1 books highly.
# User 28813 has rated 1 books highly.
# User 28840 has rated 1 books highly.
# User 28865 has rated 2 books highly.
# User 28899 has rated 1 books highly.
# User 29012 has rated 1 books highly.
# User 29028 has rated 1 books highly.
# User 29056 has rated 1 books highly.
# User 29101 has rated 1 books highly.
# User 29163 has rated 1 books highly.
# User 29182 has rated 1 books highly.
# User 29204 has rated 1 books highly.
# User 29209 has rated 2 books highly.
# User 29259 has rated 4 books highly.
# User 29340 has rated 1 books highly.
# User 29380 has rated 1 books highly.
# User 29381 has rated 1 books highly.
# User 29394 has rated 1 books highly.
# User 29419 has rated 1 books highly.
# User 29429 has rated 1 books highly.
# User 29486 has rated 2 books highly.
# User 29498 has rated 1 books highly.
# User 29508 has rated 1 books highly.
# User 29512 has rated 1 books highly.
# User 29526 has rated 5 books highly.
# User 29539 has rated 1 books highly.
# User 29570 has rated 1 books highly.
# User 29615 has rated 1 books highly.
# User 29789 has rated 1 books highly.
# User 29805 has rated 1 books highly.
# User 29855 has rated 1 books highly.
# User 29859 has rated 1 books highly.
# User 29905 has rated 1 books highly.
# User 29915 has rated 1 books highly.
# User 29944 has rated 1 books highly.
# User 30022 has rated 1 books highly.
# User 30029 has rated 2 books highly.
# User 30081 has rated 3 books highly.
# User 30116 has rated 1 books highly.
# User 30127 has rated 1 books highly.
# User 30182 has rated 1 books highly.
# User 30214 has rated 1 books highly.
# User 30245 has rated 1 books highly.
# User 30261 has rated 1 books highly.
# User 30273 has rated 1 books highly.
# User 30276 has rated 2 books highly.
# User 30295 has rated 1 books highly.
# User 30297 has rated 1 books highly.
# User 30316 has rated 1 books highly.
# User 30373 has rated 1 books highly.
# User 30385 has rated 1 books highly.
# User 30387 has rated 1 books highly.
# User 30402 has rated 1 books highly.
# User 30414 has rated 1 books highly.
# User 30445 has rated 1 books highly.
# User 30487 has rated 5 books highly.
# User 30489 has rated 1 books highly.
# User 30495 has rated 1 books highly.
# User 30507 has rated 1 books highly.
# User 30511 has rated 4 books highly.
# User 30514 has rated 1 books highly.
# User 30531 has rated 4 books highly.
# User 30533 has rated 4 books highly.
# User 30543 has rated 1 books highly.
# User 30560 has rated 1 books highly.
# User 30565 has rated 1 books highly.
# User 30570 has rated 1 books highly.
# User 30594 has rated 1 books highly.
# User 30629 has rated 1 books highly.
# User 30645 has rated 1 books highly.
# User 30711 has rated 3 books highly.
# User 30712 has rated 1 books highly.
# User 30716 has rated 1 books highly.
# User 30727 has rated 1 books highly.
# User 30728 has rated 1 books highly.
# User 30735 has rated 2 books highly.
# User 30766 has rated 1 books highly.
# User 30770 has rated 1 books highly.
# User 30776 has rated 1 books highly.
# User 30787 has rated 1 books highly.
# User 30806 has rated 1 books highly.
# User 30810 has rated 1 books highly.
# User 30848 has rated 1 books highly.
# User 30865 has rated 1 books highly.
# User 30898 has rated 1 books highly.
# User 30906 has rated 2 books highly.
# User 30933 has rated 1 books highly.
# User 30968 has rated 2 books highly.
# User 30972 has rated 2 books highly.
# User 30985 has rated 3 books highly.
# User 30989 has rated 1 books highly.
# User 30994 has rated 3 books highly.
# User 31008 has rated 1 books highly.
# User 31038 has rated 1 books highly.
# User 31039 has rated 1 books highly.
# User 31040 has rated 2 books highly.
# User 31050 has rated 1 books highly.
# User 31078 has rated 1 books highly.
# User 31094 has rated 1 books highly.
# User 31116 has rated 1 books highly.
# User 31158 has rated 1 books highly.
# User 31185 has rated 1 books highly.
# User 31226 has rated 1 books highly.
# User 31229 has rated 1 books highly.
# User 31235 has rated 1 books highly.
# User 31252 has rated 1 books highly.
# User 31299 has rated 1 books highly.
# User 31303 has rated 1 books highly.
# User 31308 has rated 1 books highly.
# User 31315 has rated 17 books highly.
# User 31322 has rated 1 books highly.
# User 31343 has rated 3 books highly.
# User 31344 has rated 1 books highly.
# User 31362 has rated 1 books highly.
# User 31386 has rated 1 books highly.
# User 31393 has rated 4 books highly.
# User 31395 has rated 1 books highly.
# User 31412 has rated 1 books highly.
# User 31431 has rated 1 books highly.
# User 31471 has rated 2 books highly.
# User 31477 has rated 1 books highly.
# User 31519 has rated 1 books highly.
# User 31528 has rated 1 books highly.
# User 31551 has rated 1 books highly.
# User 31556 has rated 5 books highly.
# User 31564 has rated 1 books highly.
# User 31677 has rated 1 books highly.
# User 31688 has rated 2 books highly.
# User 31701 has rated 1 books highly.
# User 31740 has rated 1 books highly.
# User 31817 has rated 1 books highly.
# User 31823 has rated 1 books highly.
# User 31826 has rated 18 books highly.
# User 31838 has rated 1 books highly.
# User 31846 has rated 3 books highly.
# User 31874 has rated 1 books highly.
# User 31889 has rated 1 books highly.
# User 31908 has rated 1 books highly.
# User 31948 has rated 2 books highly.
# User 31950 has rated 1 books highly.
# User 31987 has rated 1 books highly.
# User 31999 has rated 1 books highly.
# User 32022 has rated 1 books highly.
# User 32028 has rated 1 books highly.
# User 32034 has rated 1 books highly.
# User 32046 has rated 1 books highly.
# User 32071 has rated 1 books highly.
# User 32077 has rated 1 books highly.
# User 32087 has rated 1 books highly.
# User 32108 has rated 1 books highly.
# User 32148 has rated 1 books highly.
# User 32154 has rated 1 books highly.
# User 32184 has rated 1 books highly.
# User 32188 has rated 3 books highly.
# User 32195 has rated 1 books highly.
# User 32239 has rated 1 books highly.
# User 32250 has rated 1 books highly.
# User 32275 has rated 1 books highly.
# User 32440 has rated 5 books highly.
# User 32516 has rated 2 books highly.
# User 32524 has rated 1 books highly.
# User 32569 has rated 1 books highly.
# User 32599 has rated 2 books highly.
# User 32627 has rated 1 books highly.
# User 32641 has rated 1 books highly.
# User 32642 has rated 1 books highly.
# User 32691 has rated 1 books highly.
# User 32721 has rated 3 books highly.
# User 32761 has rated 1 books highly.
# User 32773 has rated 8 books highly.
# User 32785 has rated 1 books highly.
# User 32791 has rated 1 books highly.
# User 32793 has rated 1 books highly.
# User 32886 has rated 1 books highly.
# User 32942 has rated 1 books highly.
# User 32964 has rated 2 books highly.
# User 32992 has rated 1 books highly.
# User 33030 has rated 2 books highly.
# User 33049 has rated 1 books highly.
# User 33094 has rated 1 books highly.
# User 33124 has rated 3 books highly.
# User 33156 has rated 1 books highly.
# User 33179 has rated 1 books highly.
# User 33185 has rated 1 books highly.
# User 33200 has rated 1 books highly.
# User 33249 has rated 1 books highly.
# User 33263 has rated 1 books highly.
# User 33269 has rated 1 books highly.
# User 33283 has rated 2 books highly.
# User 33319 has rated 2 books highly.
# User 33321 has rated 1 books highly.
# User 33391 has rated 1 books highly.
# User 33395 has rated 1 books highly.
# User 33474 has rated 1 books highly.
# User 33477 has rated 1 books highly.
# User 33517 has rated 1 books highly.
# User 33576 has rated 1 books highly.
# User 33585 has rated 1 books highly.
# User 33598 has rated 1 books highly.
# User 33656 has rated 1 books highly.
# User 33665 has rated 1 books highly.
# User 33681 has rated 1 books highly.
# User 33727 has rated 1 books highly.
# User 33790 has rated 1 books highly.
# User 33816 has rated 2 books highly.
# User 33818 has rated 8 books highly.
# User 33836 has rated 1 books highly.
# User 33897 has rated 1 books highly.
# User 33933 has rated 2 books highly.
# User 33958 has rated 1 books highly.
# User 33974 has rated 1 books highly.
# User 33993 has rated 1 books highly.
# User 33999 has rated 2 books highly.
# User 34007 has rated 1 books highly.
# User 34034 has rated 1 books highly.
# User 34077 has rated 1 books highly.
# User 34127 has rated 1 books highly.
# User 34152 has rated 1 books highly.
# User 34154 has rated 1 books highly.
# User 34174 has rated 1 books highly.
# User 34181 has rated 1 books highly.
# User 34193 has rated 1 books highly.
# User 34205 has rated 1 books highly.
# User 34215 has rated 1 books highly.
# User 34300 has rated 1 books highly.
# User 34314 has rated 1 books highly.
# User 34344 has rated 1 books highly.
# User 34526 has rated 1 books highly.
# User 34539 has rated 1 books highly.
# User 34557 has rated 1 books highly.
# User 34588 has rated 2 books highly.
# User 34592 has rated 1 books highly.
# User 34655 has rated 1 books highly.
# User 34657 has rated 1 books highly.
# User 34716 has rated 1 books highly.
# User 34735 has rated 1 books highly.
# User 34740 has rated 1 books highly.
# User 34748 has rated 1 books highly.
# User 34767 has rated 1 books highly.
# User 34776 has rated 1 books highly.
# User 34837 has rated 1 books highly.
# User 34864 has rated 1 books highly.
# User 34890 has rated 1 books highly.
# User 34908 has rated 1 books highly.
# User 34936 has rated 1 books highly.
# User 34957 has rated 1 books highly.
# User 34967 has rated 1 books highly.
# User 35014 has rated 1 books highly.
# User 35033 has rated 1 books highly.
# User 35072 has rated 1 books highly.
# User 35134 has rated 1 books highly.
# User 35179 has rated 1 books highly.
# User 35185 has rated 1 books highly.
# User 35191 has rated 1 books highly.
# User 35216 has rated 1 books highly.
# User 35231 has rated 1 books highly.
# User 35238 has rated 1 books highly.
# User 35243 has rated 1 books highly.
# User 35244 has rated 1 books highly.
# User 35288 has rated 1 books highly.
# User 35320 has rated 2 books highly.
# User 35321 has rated 1 books highly.
# User 35376 has rated 1 books highly.
# User 35407 has rated 1 books highly.
# User 35424 has rated 3 books highly.
# User 35466 has rated 1 books highly.
# User 35537 has rated 1 books highly.
# User 35567 has rated 1 books highly.
# User 35599 has rated 1 books highly.
# User 35612 has rated 1 books highly.
# User 35631 has rated 1 books highly.
# User 35704 has rated 3 books highly.
# User 35718 has rated 1 books highly.
# User 35826 has rated 1 books highly.
# User 35831 has rated 1 books highly.
# User 35841 has rated 1 books highly.
# User 35842 has rated 1 books highly.
# User 35845 has rated 1 books highly.
# User 35857 has rated 2 books highly.
# User 35859 has rated 15 books highly.
# User 35918 has rated 2 books highly.
# User 35925 has rated 1 books highly.
# User 35931 has rated 1 books highly.
# User 35963 has rated 1 books highly.
# User 35979 has rated 1 books highly.
# User 35998 has rated 1 books highly.
# User 36003 has rated 3 books highly.
# User 36043 has rated 1 books highly.
# User 36103 has rated 1 books highly.
# User 36121 has rated 1 books highly.
# User 36135 has rated 3 books highly.
# User 36157 has rated 1 books highly.
# User 36235 has rated 1 books highly.
# User 36256 has rated 2 books highly.
# User 36269 has rated 1 books highly.
# User 36286 has rated 1 books highly.
# User 36307 has rated 1 books highly.
# User 36327 has rated 2 books highly.
# User 36380 has rated 1 books highly.
# User 36472 has rated 1 books highly.
# User 36506 has rated 1 books highly.
# User 36540 has rated 1 books highly.
# User 36554 has rated 2 books highly.
# User 36562 has rated 1 books highly.
# User 36606 has rated 4 books highly.
# User 36609 has rated 3 books highly.
# ...
# User 267184 has rated 2 books highly.
# User 267187 has rated 1 books highly.
# User 267267 has rated 1 books highly.
# User 267297 has rated 1 books highly.
# User 267300 has rated 1 books highly.
# User 267313 has rated 1 books highly.
# User 267326 has rated 2 books highly.
# User 267354 has rated 2 books highly.
# User 267442 has rated 1 books highly.
# User 267453 has rated 1 books highly.
# User 267480 has rated 1 books highly.
# User 267502 has rated 1 books highly.
# User 267510 has rated 3 books highly.
# User 267529 has rated 1 books highly.
# User 267537 has rated 1 books highly.
# User 267553 has rated 1 books highly.
# User 267567 has rated 1 books highly.
# User 267596 has rated 2 books highly.
# User 267621 has rated 1 books highly.
# User 267624 has rated 1 books highly.
# User 267635 has rated 1 books highly.
# User 267644 has rated 1 books highly.
# User 267645 has rated 3 books highly.
# User 267703 has rated 1 books highly.
# User 267758 has rated 1 books highly.
# User 267798 has rated 1 books highly.
# User 267802 has rated 1 books highly.
# User 267812 has rated 1 books highly.
# User 267821 has rated 1 books highly.
# User 267827 has rated 1 books highly.
# User 267830 has rated 2 books highly.
# User 267878 has rated 1 books highly.
# User 267897 has rated 1 books highly.
# User 267916 has rated 1 books highly.
# User 267937 has rated 1 books highly.
# User 267984 has rated 1 books highly.
# User 267990 has rated 1 books highly.
# User 268022 has rated 1 books highly.
# User 268030 has rated 5 books highly.
# User 268031 has rated 1 books highly.
# User 268032 has rated 4 books highly.
# User 268051 has rated 1 books highly.
# User 268074 has rated 1 books highly.
# User 268090 has rated 1 books highly.
# User 268110 has rated 4 books highly.
# User 268127 has rated 1 books highly.
# User 268153 has rated 1 books highly.
# User 268165 has rated 1 books highly.
# User 268179 has rated 1 books highly.
# User 268191 has rated 1 books highly.
# User 268239 has rated 1 books highly.
# User 268244 has rated 1 books highly.
# User 268262 has rated 1 books highly.
# User 268292 has rated 1 books highly.
# User 268300 has rated 6 books highly.
# User 268315 has rated 1 books highly.
# User 268343 has rated 1 books highly.
# User 268419 has rated 1 books highly.
# User 268451 has rated 1 books highly.
# User 268538 has rated 1 books highly.
# User 268540 has rated 1 books highly.
# User 268544 has rated 2 books highly.
# User 268613 has rated 1 books highly.
# User 268618 has rated 1 books highly.
# User 268622 has rated 1 books highly.
# User 268639 has rated 1 books highly.
# User 268675 has rated 1 books highly.
# User 268682 has rated 1 books highly.
# User 268690 has rated 1 books highly.
# User 268734 has rated 1 books highly.
# User 268761 has rated 1 books highly.
# User 268774 has rated 1 books highly.
# User 268784 has rated 1 books highly.
# User 268786 has rated 1 books highly.
# User 268788 has rated 1 books highly.
# User 268898 has rated 1 books highly.
# User 268913 has rated 1 books highly.
# User 268927 has rated 1 books highly.
# User 268932 has rated 3 books highly.
# User 268987 has rated 1 books highly.
# User 269060 has rated 1 books highly.
# User 269069 has rated 1 books highly.
# User 269105 has rated 1 books highly.
# User 269140 has rated 2 books highly.
# User 269179 has rated 1 books highly.
# User 269230 has rated 1 books highly.
# User 269231 has rated 1 books highly.
# User 269245 has rated 1 books highly.
# User 269273 has rated 1 books highly.
# User 269303 has rated 1 books highly.
# User 269313 has rated 1 books highly.
# User 269340 has rated 2 books highly.
# User 269352 has rated 1 books highly.
# User 269378 has rated 1 books highly.
# User 269386 has rated 3 books highly.
# User 269410 has rated 1 books highly.
# User 269451 has rated 1 books highly.
# User 269514 has rated 1 books highly.
# User 269539 has rated 1 books highly.
# User 269557 has rated 1 books highly.
# User 269566 has rated 4 books highly.
# User 269677 has rated 2 books highly.
# User 269719 has rated 1 books highly.
# User 269754 has rated 1 books highly.
# User 269773 has rated 1 books highly.
# User 269782 has rated 1 books highly.
# User 269799 has rated 2 books highly.
# User 269808 has rated 2 books highly.
# User 269815 has rated 1 books highly.
# User 269835 has rated 3 books highly.
# User 269841 has rated 1 books highly.
# User 269886 has rated 1 books highly.
# User 269945 has rated 1 books highly.
# User 269946 has rated 1 books highly.
# User 269988 has rated 1 books highly.
# User 270020 has rated 1 books highly.
# User 270029 has rated 1 books highly.
# User 270046 has rated 1 books highly.
# User 270051 has rated 1 books highly.
# User 270091 has rated 1 books highly.
# User 270134 has rated 1 books highly.
# User 270156 has rated 3 books highly.
# User 270187 has rated 1 books highly.
# User 270195 has rated 1 books highly.
# User 270234 has rated 1 books highly.
# User 270263 has rated 1 books highly.
# User 270339 has rated 1 books highly.
# User 270352 has rated 1 books highly.
# User 270368 has rated 1 books highly.
# User 270380 has rated 1 books highly.
# User 270522 has rated 1 books highly.
# User 270537 has rated 1 books highly.
# User 270551 has rated 1 books highly.
# User 270554 has rated 4 books highly.
# User 270605 has rated 3 books highly.
# User 270685 has rated 1 books highly.
# User 270713 has rated 4 books highly.
# User 270737 has rated 3 books highly.
# User 270738 has rated 1 books highly.
# User 270742 has rated 1 books highly.
# User 270758 has rated 1 books highly.
# User 270784 has rated 1 books highly.
# User 270801 has rated 3 books highly.
# User 270820 has rated 4 books highly.
# User 270838 has rated 3 books highly.
# User 270863 has rated 1 books highly.
# User 270864 has rated 1 books highly.
# User 270881 has rated 1 books highly.
# User 270896 has rated 1 books highly.
# User 270973 has rated 1 books highly.
# User 271054 has rated 1 books highly.
# User 271058 has rated 1 books highly.
# User 271086 has rated 1 books highly.
# User 271124 has rated 1 books highly.
# User 271155 has rated 1 books highly.
# User 271156 has rated 1 books highly.
# User 271176 has rated 3 books highly.
# User 271195 has rated 2 books highly.
# User 271206 has rated 1 books highly.
# User 271241 has rated 1 books highly.
# User 271303 has rated 1 books highly.
# User 271306 has rated 1 books highly.
# User 271354 has rated 1 books highly.
# User 271374 has rated 1 books highly.
# User 271425 has rated 1 books highly.
# User 271437 has rated 1 books highly.
# User 271448 has rated 3 books highly.
# User 271476 has rated 1 books highly.
# User 271516 has rated 1 books highly.
# User 271531 has rated 3 books highly.
# User 271542 has rated 1 books highly.
# User 271557 has rated 1 books highly.
# User 271558 has rated 1 books highly.
# User 271567 has rated 1 books highly.
# User 271587 has rated 1 books highly.
# User 271589 has rated 1 books highly.
# User 271610 has rated 1 books highly.
# User 271622 has rated 1 books highly.
# User 271645 has rated 1 books highly.
# User 271655 has rated 1 books highly.
# User 271705 has rated 7 books highly.
# User 271859 has rated 1 books highly.
# User 271861 has rated 1 books highly.
# User 271883 has rated 1 books highly.
# User 272008 has rated 1 books highly.
# User 272077 has rated 1 books highly.
# User 272140 has rated 1 books highly.
# User 272144 has rated 1 books highly.
# User 272202 has rated 1 books highly.
# User 272225 has rated 2 books highly.
# User 272233 has rated 1 books highly.
# User 272324 has rated 1 books highly.
# User 272373 has rated 1 books highly.
# User 272388 has rated 1 books highly.
# User 272395 has rated 1 books highly.
# User 272407 has rated 1 books highly.
# User 272441 has rated 1 books highly.
# User 272445 has rated 1 books highly.
# User 272564 has rated 1 books highly.
# User 272573 has rated 2 books highly.
# User 272705 has rated 1 books highly.
# User 272706 has rated 1 books highly.
# User 272749 has rated 1 books highly.
# User 272763 has rated 1 books highly.
# User 272786 has rated 1 books highly.
# User 272838 has rated 1 books highly.
# User 272885 has rated 1 books highly.
# User 272897 has rated 1 books highly.
# User 272943 has rated 1 books highly.
# User 272961 has rated 2 books highly.
# User 273037 has rated 1 books highly.
# User 273086 has rated 3 books highly.
# User 273089 has rated 2 books highly.
# User 273159 has rated 1 books highly.
# User 273177 has rated 1 books highly.
# User 273197 has rated 1 books highly.
# User 273270 has rated 1 books highly.
# User 273283 has rated 1 books highly.
# User 273336 has rated 2 books highly.
# User 273341 has rated 1 books highly.
# User 273342 has rated 1 books highly.
# User 273344 has rated 1 books highly.
# User 273376 has rated 2 books highly.
# User 273439 has rated 1 books highly.
# User 273440 has rated 1 books highly.
# User 273483 has rated 1 books highly.
# User 273552 has rated 1 books highly.
# User 273586 has rated 1 books highly.
# User 273635 has rated 2 books highly.
# User 273703 has rated 1 books highly.
# User 273718 has rated 2 books highly.
# User 273738 has rated 1 books highly.
# User 273794 has rated 1 books highly.
# User 273813 has rated 1 books highly.
# User 273857 has rated 1 books highly.
# User 273880 has rated 1 books highly.
# User 273881 has rated 1 books highly.
# User 273906 has rated 1 books highly.
# User 273923 has rated 1 books highly.
# User 273959 has rated 1 books highly.
# User 273976 has rated 1 books highly.
# User 273979 has rated 1 books highly.
# User 274004 has rated 1 books highly.
# User 274056 has rated 2 books highly.
# User 274061 has rated 12 books highly.
# User 274111 has rated 2 books highly.
# User 274135 has rated 1 books highly.
# User 274194 has rated 1 books highly.
# User 274215 has rated 1 books highly.
# User 274227 has rated 1 books highly.
# User 274273 has rated 1 books highly.
# User 274282 has rated 1 books highly.
# User 274301 has rated 4 books highly.
# User 274308 has rated 2 books highly.
# User 274319 has rated 1 books highly.
# User 274325 has rated 2 books highly.
# User 274361 has rated 1 books highly.
# User 274380 has rated 2 books highly.
# User 274393 has rated 3 books highly.
# User 274418 has rated 1 books highly.
# User 274421 has rated 1 books highly.
# User 274546 has rated 1 books highly.
# User 274549 has rated 1 books highly.
# User 274633 has rated 1 books highly.
# User 274644 has rated 1 books highly.
# User 274656 has rated 1 books highly.
# User 274688 has rated 1 books highly.
# User 274700 has rated 1 books highly.
# User 274707 has rated 1 books highly.
# User 274718 has rated 1 books highly.
# User 274720 has rated 1 books highly.
# User 274808 has rated 1 books highly.
# User 274823 has rated 1 books highly.
# User 274898 has rated 1 books highly.
# User 274904 has rated 1 books highly.
# User 274959 has rated 1 books highly.
# User 274979 has rated 1 books highly.
# User 274983 has rated 1 books highly.
# User 275020 has rated 1 books highly.
# User 275075 has rated 1 books highly.
# User 275094 has rated 1 books highly.
# User 275118 has rated 1 books highly.
# User 275128 has rated 1 books highly.
# User 275154 has rated 3 books highly.
# User 275179 has rated 1 books highly.
# User 275240 has rated 1 books highly.
# User 275274 has rated 1 books highly.
# User 275276 has rated 3 books highly.
# User 275281 has rated 1 books highly.
# User 275306 has rated 3 books highly.
# User 275321 has rated 1 books highly.
# User 275322 has rated 1 books highly.
# User 275364 has rated 1 books highly.
# User 275374 has rated 1 books highly.
# User 275401 has rated 1 books highly.
# User 275429 has rated 1 books highly.
# User 275439 has rated 1 books highly.
# User 275459 has rated 1 books highly.
# User 275470 has rated 1 books highly.
# User 275473 has rated 1 books highly.
# User 275476 has rated 2 books highly.
# User 275519 has rated 1 books highly.
# User 275520 has rated 2 books highly.
# User 275531 has rated 1 books highly.
# User 275630 has rated 1 books highly.
# User 275638 has rated 1 books highly.
# User 275677 has rated 1 books highly.
# User 275758 has rated 1 books highly.
# User 275793 has rated 1 books highly.
# User 275800 has rated 1 books highly.
# User 275807 has rated 1 books highly.
# User 275906 has rated 1 books highly.
# User 275909 has rated 1 books highly.
# User 275922 has rated 3 books highly.
# User 275970 has rated 6 books highly.
# User 276017 has rated 1 books highly.
# User 276038 has rated 1 books highly.
# User 276042 has rated 1 books highly.
# User 276046 has rated 1 books highly.
# User 276071 has rated 1 books highly.
# User 276077 has rated 1 books highly.
# User 276147 has rated 1 books highly.
# User 276165 has rated 2 books highly.
# User 276167 has rated 1 books highly.
# User 276226 has rated 1 books highly.
# User 276253 has rated 1 books highly.
# User 276275 has rated 1 books highly.
# User 276307 has rated 2 books highly.
# User 276311 has rated 1 books highly.
# User 276328 has rated 1 books highly.
# User 276372 has rated 1 books highly.
# User 276463 has rated 2 books highly.
# User 276556 has rated 1 books highly.
# User 276563 has rated 1 books highly.
# User 276680 has rated 5 books highly.
# User 276681 has rated 1 books highly.
# User 276683 has rated 1 books highly.
# User 276786 has rated 1 books highly.
# User 276896 has rated 1 books highly.
# User 276925 has rated 1 books highly.
# User 276953 has rated 1 books highly.
# User 277042 has rated 2 books highly.
# User 277051 has rated 1 books highly.
# User 277085 has rated 1 books highly.
# User 277094 has rated 1 books highly.
# User 277107 has rated 1 books highly.
# User 277124 has rated 1 books highly.
# User 277143 has rated 1 books highly.
# User 277195 has rated 1 books highly.
# User 277197 has rated 1 books highly.
# User 277203 has rated 1 books highly.
# User 277212 has rated 1 books highly.
# User 277246 has rated 1 books highly.
# User 277253 has rated 1 books highly.
# User 277317 has rated 1 books highly.
# User 277427 has rated 7 books highly.
# User 277435 has rated 1 books highly.
# User 277517 has rated 1 books highly.
# User 277523 has rated 3 books highly.
# User 277556 has rated 1 books highly.
# User 277562 has rated 1 books highly.
# User 277575 has rated 1 books highly.
# User 277629 has rated 2 books highly.
# User 277639 has rated 2 books highly.
# User 277650 has rated 1 books highly.
# User 277710 has rated 1 books highly.
# User 277722 has rated 1 books highly.
# User 277743 has rated 1 books highly.
# User 277761 has rated 1 books highly.
# User 277764 has rated 1 books highly.
# User 277783 has rated 1 books highly.
# User 277794 has rated 1 books highly.
# User 277803 has rated 1 books highly.
# User 277827 has rated 1 books highly.
# User 277828 has rated 1 books highly.
# User 277901 has rated 1 books highly.
# User 277928 has rated 2 books highly.
# User 277945 has rated 1 books highly.
# User 277958 has rated 1 books highly.
# User 277959 has rated 1 books highly.
# User 277969 has rated 1 books highly.
# User 277982 has rated 1 books highly.
# User 277997 has rated 1 books highly.
# User 278007 has rated 1 books highly.
# User 278026 has rated 2 books highly.
# User 278075 has rated 1 books highly.
# User 278079 has rated 1 books highly.
# User 278100 has rated 1 books highly.
# User 278112 has rated 1 books highly.
# User 278119 has rated 1 books highly.
# User 278122 has rated 1 books highly.
# User 278131 has rated 1 books highly.
# User 278137 has rated 2 books highly.
# User 278155 has rated 1 books highly.
# User 278188 has rated 2 books highly.
# User 278194 has rated 2 books highly.
# User 278202 has rated 1 books highly.
# User 278221 has rated 1 books highly.
# User 278243 has rated 1 books highly.
# User 278259 has rated 1 books highly.
# User 278297 has rated 1 books highly.
# User 278319 has rated 1 books highly.
# User 278333 has rated 1 books highly.
# User 278388 has rated 1 books highly.
# User 278390 has rated 1 books highly.
# User 278398 has rated 1 books highly.
# User 278418 has rated 1 books highly.
# User 278422 has rated 1 books highly.
# User 278461 has rated 1 books highly.
# User 278483 has rated 1 books highly.
# User 278525 has rated 1 books highly.
# User 278541 has rated 1 books highly.
# User 278554 has rated 1 books highly.
# User 278633 has rated 2 books highly.
# User 278641 has rated 1 books highly.
# User 278663 has rated 1 books highly.
# User 278698 has rated 1 books highly.
# User 278740 has rated 1 books highly.
# User 278773 has rated 1 books highly.
# User 278843 has rated 1 books highly.
# User 278846 has rated 1 books highly.

# %%
recommendations = {}
k = 50

for user_id, user_embedding in user_to_embed.items():
    # reshape user embedding for cosine_similarity (needs 2D array)
    user_emb_2d = user_embedding.reshape(1, -1)
    
    # compute cosine similarity between user and all books
    similarities = cosine_similarity(user_emb_2d, tfidf_matrix).flatten()
    
    # get the unmasked books for this user
    unmasked_titles = {title for title, _ in user_books[user_id]}
    
    # create a list of (similarity, index, title) for books NOT in unmasked
    candidate_books = [
        (similarities[idx], idx, title)
        for idx, title in enumerate(df.index)
        if title not in unmasked_titles
    ] # because unmasked contains books that we know the user has read/rated
    
    # sort by similarity (descending) and get top k
    candidate_books.sort(reverse=True, key=lambda x: x[0])
    top_k = candidate_books[:k]
    
    # Extract just the titles
    recommendations[user_id] = [title for _, _, title in top_k]

# view sample recommendations
sample_user = list(recommendations.keys())[0]
print(f"Top {k} recommendations for user {sample_user}:")
for i, book in enumerate(recommendations[sample_user], 1):
    print(f"{i}. {book}")
# Out:
# Top 50 recommendations for user 26:
# 1. follow your heart
# 2. an american childhood
# 3. three tales
# 4. savage inequalities: children in america's schools
# 5. journey to the end of the night
# 6. hiroshima
# 7. a tree grows in brooklyn
# 8. the grapes of wrath
# 9. the amateur marriage
# 10. the prophet
# 11. black boy
# 12. the art of loving
# 13. the moviegoer
# 14. the house on mango street
# 15. wild swans: three daughters of china
# 16. autobiography of a yogi
# 17. endymion
# 18. the rainmaker
# 19. the secret garden
# 20. shopgirl
# 21. the color purple
# 22. different seasons
# 23. a portrait of the artist as a young man
# 24. how to win friends and influence people
# 25. youngblood hawke
# 26. the feminine mystique
# 27. ferdydurke
# 28. all about love: new visions
# 29. black elk speaks: being the life story of a holy man of the oglala sioux
# 30. katherine
# 31. angela's ashes
# 32. never let me go
# 33. sula
# 34. arctic dreams
# 35. cancer ward
# 36. of mice and men
# 37. the adolescent
# 38. main street
# 39. a personal matter
# 40. suzanne's diary for nicholas
# 41. boy's life
# 42. midnight in the garden of good and evil
# 43. a separate peace
# 44. out of this world
# 45. the untouchables
# 46. witness
# 47. the mambo kings play songs of love
# 48. the richest man in babylon
# 49. accordion crimes
# 50. dracula

# %%
recommendations
# Out:
# {26: ['follow your heart',
#   'an american childhood',
#   'three tales',
#   "savage inequalities: children in america's schools",
#   'journey to the end of the night',
#   'hiroshima',
#   'a tree grows in brooklyn',
#   'the grapes of wrath',
#   'the amateur marriage',
#   'the prophet',
#   'black boy',
#   'the art of loving',
#   'the moviegoer',
#   'the house on mango street',
#   'wild swans: three daughters of china',
#   'autobiography of a yogi',
#   'endymion',
#   'the rainmaker',
#   'the secret garden',
#   'shopgirl',
#   'the color purple',
#   'different seasons',
#   'a portrait of the artist as a young man',
#   'how to win friends and influence people',
#   'youngblood hawke',
#   'the feminine mystique',
#   'ferdydurke',
#   'all about love: new visions',
#   'black elk speaks: being the life story of a holy man of the oglala sioux',
#   'katherine',
#   "angela's ashes",
#   'never let me go',
#   'sula',
#   'arctic dreams',
#   'cancer ward',
#   'of mice and men',
#   'the adolescent',
#   'main street',
#   'a personal matter',
#   "suzanne's diary for nicholas",
#   "boy's life",
#   'midnight in the garden of good and evil',
#   'a separate peace',
#   'out of this world',
#   'the untouchables',
#   'witness',
#   'the mambo kings play songs of love',
#   'the richest man in babylon',
#   'accordion crimes',
#   'dracula'],
#  51: ['stranger in a strange land',
#   'the sicilian',
#   'forever . . .',
#   'firefly summer',
#   'black sunday',
#   'age of iron',
#   'the firm',
#   "liar's poker",
#   'peter pan',
#   'paint it black',
#   'deception point',
#   'the brethren',
#   'the partner',
#   "the botany of desire: a plant's-eye view of the world",
#   'money',
#   "anil's ghost",
#   'the rainmaker',
#   'cradle to cradle: remaking the way we make things',
#   'around the world in eighty days',
#   'atlas shrugged',
#   'a yellow raft in blue water',
#   'great expectations',
#   'the king of torts',
#   'holy the firm',
#   'public secrets',
#   'my year of meats',
#   'chronicle of a death foretold',
#   'art and beauty in the middle ages',
#   'dispatches',
#   'fiasco',
#   'narcissus and goldmund',
#   'a frolic of his own',
#   'the client',
#   'the eyes of darkness',
#   'runaway',
#   'no ordinary time: franklin and eleanor roosevelt: the home front in world war ii',
#   'the four loves',
#   'the capricorn stone',
#   'from a buick 8',
#   "the time traveler's wife",
#   'a brief history of time',
#   'company',
#   'the guns of august',
#   'the secret garden',
#   'enchantment',
#   'a home at the end of the world',
#   'a briefer history of time',
#   'girlfriend in a coma',
#   'shadows',
#   'the origin of consciousness in the breakdown of the bicameral mind'],
#  53: ['watership down',
#   'gone south',
#   'salem falls',
#   'rising sun',
#   'carter beats the devil',
#   'neverwhere',
#   'the book of embraces',
#   'friday',
#   'casino royale',
#   "it can't happen here",
#   'den of thieves',
#   'the grapes of wrath',
#   'vineland',
#   'the sound and the fury',
#   'the tale of the flopsy bunnies',
#   'the beach house',
#   'waiting for the barbarians',
#   'famous last words',
#   'geek love',
#   'letters home',
#   'tales from watership down',
#   'amsterdam',
#   'leviathan',
#   'a tree grows in brooklyn',
#   'sideways',
#   'the blank slate: the modern denial of human nature',
#   'frankenstein',
#   "one flew over the cuckoo's nest",
#   'the noonday demon: an atlas of depression',
#   'songmaster',
#   'james and the giant peach',
#   'the scarlet letter',
#   'the outsider',
#   'how to win friends and influence people',
#   'anthem',
#   'the inheritors',
#   'the power broker: robert moses and the fall of new york',
#   'darkfall',
#   'runaway',
#   'cane river',
#   'the guns of august',
#   'darkness visible: a memoir of madness',
#   'living to tell the tale',
#   '1421: the year china discovered america',
#   'lord of the flies',
#   'the ice storm',
#   'island',
#   'election',
#   'enchantress from the stars',
#   'of love and other demons'],
#  91: ['money',
#   'slaughterhouse-five',
#   'mao ii',
#   'here is new york',
#   'the long walk',
#   'lord jim',
#   'the dark half',
#   'brave new world',
#   'stinger',
#   'life of pi',
#   "the pilgrim's progress",
#   'the subterraneans',
#   'how green was my valley',
#   '1984',
#   'the prophet',
#   'the mermaids singing',
#   "beauty's punishment",
#   'the adolescent',
#   'the natural',
#   'exit to eden',
#   "world's fair",
#   'drowning ruth',
#   'the child in time',
#   'invisible man',
#   'to have and to hold',
#   'human croquet',
#   'the dream of scipio',
#   'spellbound',
#   'harvesting the heart',
#   'bleak house',
#   'american caesar: douglas macarthur 1880-1964',
#   'a different mirror: a history of multicultural america',
#   'the shadow of the wind',
#   'when the elephants dance',
#   'the moviegoer',
#   'english passengers',
#   'journey to the end of the night',
#   'cry to heaven',
#   'written on the body',
#   'the master and margarita',
#   'pnin',
#   'view with a grain of sand: selected poems',
#   'high fidelity',
#   'beauty',
#   'the cricket in times square',
#   'the fuck-up',
#   'black beauty',
#   'from a buick 8',
#   'the basketball diaries',
#   'witness'],
#  114: ['the big bad wolf',
#   'pop goes the weasel',
#   'you belong to me',
#   'ricochet',
#   'gone for good',
#   'earthbound',
#   'tourist season',
#   'the lovely bones',
#   'the dain curse',
#   'the pelican brief',
#   'chasing the dime',
#   'dr. seuss goes to war: the world war ii editorial cartoons of theodor seuss geisel',
#   'the falls',
#   'nothing lasts forever',
#   'open house',
#   'the picture of dorian gray',
#   'atlas shrugged',
#   "lucifer's shadow",
#   'the copper beech',
#   'thinner',
#   'pope joan',
#   'v.',
#   'mary queen of scots',
#   'public secrets',
#   'in cold blood',
#   'great expectations',
#   'midnight in the garden of good and evil',
#   'awakenings',
#   'zombie',
#   'the silence of the lambs',
#   '10 lb penalty',
#   'the wall',
#   'crime and punishment',
#   'exquisite corpse',
#   'never let me go',
#   'a break with charity: a story about the salem witch trials',
#   'color: a natural history of the palette',
#   'insomnia',
#   'demon in my view',
#   "sunny chandler's return",
#   'life support',
#   'kingdom come',
#   'the autograph man',
#   'house of the sleeping beauties and other stories',
#   "if on a winter's night a traveler",
#   'velocity',
#   'the shining',
#   'chronicle of a death foretold',
#   'a short history of nearly everything',
#   'the turn of the screw'],
#  183: ['el nombre de la rosa',
#   'the universe in a nutshell',
#   'el coronel no tiene quien le escriba',
#   'las aventuras de tom sawyer',
#   'amarse con los ojos abiertos',
#   'del amor y otros demonios',
#   'como agua para chocolate',
#   'rabia',
#   'the prince',
#   'the gun seller',
#   'el retrato de dorian gray',
#   'ojos de perro azul',
#   'el perfume: historia de un asesino',
#   'ubik',
#   'cumbres borrascosas',
#   'all around the town',
#   'survival in auschwitz',
#   'starship titanic',
#   'caligula',
#   'blade runner',
#   'exile and the kingdom',
#   'for whom the bell tolls',
#   'lost horizon',
#   "when heaven and earth changed places: a vietnamese woman's journey from war to peace",
#   'les jeux sont faits',
#   'a scanner darkly',
#   'the divine comedy',
#   'a tale of two cities',
#   'paint it black',
#   'madame bovary',
#   'tales from watership down',
#   'the key to rebecca',
#   "in search of captain zero: a surfer's road trip beyond the end of the road",
#   'like water for chocolate',
#   'le petit prince',
#   'the power broker: robert moses and the fall of new york',
#   'the stories of vladimir nabokov',
#   'seven plays',
#   'la chute',
#   'the noonday demon: an atlas of depression',
#   'the book of questions',
#   'a painted house',
#   'lightning',
#   'the dark half',
#   'anna karenina',
#   'the picture of dorian gray',
#   'alaska',
#   'the wonderful story of henry sugar and six more',
#   'shadowland',
#   'how to win friends and influence people'],
#  185: ['the children of henry viii',
#   'blessings',
#   'the turn of the screw',
#   'identity',
#   'the falls',
#   'persuasion',
#   'tender is the night',
#   'insomnia',
#   "if on a winter's night a traveler",
#   'the girl in a swing',
#   'the greatest generation',
#   'the brothers k',
#   'strange pilgrims',
#   'the shadow of the wind',
#   'the amateur marriage',
#   'emma',
#   'tamsin',
#   'black dogs',
#   'the homecoming',
#   'the child in time',
#   'the year of the death of ricardo reis',
#   'friday',
#   'people of the lie: the hope for healing human evil',
#   'gift from the sea',
#   'self',
#   'swan song',
#   'american gods',
#   'monster',
#   'the farming of bones',
#   'the real thing',
#   'the reluctant reformer',
#   'confessions of an ugly stepsister',
#   'mr. murder',
#   'angels',
#   'beach music',
#   'diary',
#   'the assault',
#   'joy in the morning',
#   "spindle's end",
#   'vanity fair',
#   'the god of small things',
#   'the adventures of sherlock holmes',
#   'the crying of lot 49',
#   'drowning ruth',
#   'fanny: being the true history of the adventures of fanny hackabout-jones',
#   'the feminine mystique',
#   'eden close',
#   'a virtuous woman',
#   'a year in provence',
#   'something wicked this way comes'],
#  242: ['i am legend',
#   'the war of the worlds',
#   'stranger in a strange land',
#   'the gods themselves',
#   'lord of light',
#   'martian time-slip',
#   'house of stairs',
#   'ape and essence',
#   'sacrament',
#   'dandelion wine',
#   'the lorax',
#   'insomnia',
#   'below the root',
#   'word of honor',
#   'poppy',
#   "wild at heart: discovering the secret of a man's soul",
#   'planet of the apes',
#   'anne of avonlea',
#   'phantoms',
#   'the moon is a harsh mistress',
#   'vanity fair',
#   'the dispossessed',
#   'neverwhere',
#   'arctic dreams',
#   'swan song',
#   'birds of america',
#   'the tale of the flopsy bunnies',
#   'demons',
#   'this alien shore',
#   'the silmarillion',
#   'james and the giant peach',
#   'the children of noisy village',
#   'danny the champion of the world',
#   'not without my daughter',
#   'the inheritors',
#   'how green was my valley',
#   'the fall of berlin 1945',
#   'the hotel new hampshire',
#   'the grapes of wrath',
#   'jurassic park',
#   'spellbound',
#   'mao ii',
#   'fiasco',
#   'house of the sleeping beauties and other stories',
#   'wonderful life: the burgess shale and the nature of history',
#   'something wicked this way comes',
#   'absolutely normal chaos',
#   'anne of green gables',
#   'a distant mirror: the calamitous 14th century',
#   'one hundred years of solitude'],
#  243: ['demian',
#   'the tale of genji',
#   'the art of loving',
#   'naomi',
#   'love poems',
#   'mother of pearl',
#   'seven types of ambiguity',
#   'side effects',
#   'story of o',
#   'the wall',
#   'the untouchable',
#   "james herriot's dog stories",
#   'exquisite corpse',
#   'carrie',
#   'the mambo kings play songs of love',
#   'madame bovary',
#   'the namesake',
#   'fugitive pieces',
#   'darkness visible: a memoir of madness',
#   'the wind-up bird chronicle',
#   'birdsong',
#   'turtle moon',
#   'a tree grows in brooklyn',
#   'falconer',
#   'forever amber',
#   'scar tissue',
#   'the greatest generation',
#   'cane river',
#   "wild at heart: discovering the secret of a man's soul",
#   'little women',
#   'pope joan',
#   'rage of angels',
#   'never let me go',
#   'the book of ruth',
#   'all about love: new visions',
#   'out',
#   'lolita',
#   'the killer angels',
#   'moon palace',
#   'my year of meats',
#   'the girl in a swing',
#   'first they killed my father: a daughter of cambodia remembers',
#   'the postman always rings twice',
#   'blessings',
#   'the rachel papers',
#   "the time traveler's wife",
#   'autobiography of a yogi',
#   'memoirs of the second world war',
#   'laughable loves',
#   'caravans'],
#  244: ['demon in my view',
#   'the wonderful story of henry sugar and six more',
#   "in harm's way: the sinking of the uss indianapolis and the extraordinary story of its survivors",
#   'timequake',
#   'hawaii',
#   'running from safety: an adventure of the spirit',
#   'my uncle oswald',
#   'rage of angels',
#   'how green was my valley',
#   'and then there were none',
#   'black boy',
#   'the enormous crocodile',
#   'gossamer',
#   'the catcher in the rye',
#   'dark visions',
#   'in the heart of the sea: the tragedy of the whaleship essex',
#   'house of the sleeping beauties and other stories',
#   'the collected stories of arthur c. clarke',
#   'alice in wonderland',
#   'the tiger rising',
#   'the crucible',
#   'a single man',
#   'the book of ruth',
#   'enchantment',
#   'people of the lie: the hope for healing human evil',
#   "the millionaire next door: the surprising secrets of america's wealthy",
#   'the talisman',
#   'the eyes of the dragon',
#   'sacrament',
#   'island',
#   'human croquet',
#   'the calvin and hobbes tenth anniversary book',
#   'amnesia moon',
#   'tiger prince',
#   'the changeling sea',
#   'the whipping boy',
#   'a little princess',
#   'danny the champion of the world',
#   'the last jew',
#   'a break with charity: a story about the salem witch trials',
#   'illusions: the adventures of a reluctant messiah',
#   'the brothers lionheart',
#   "charlotte's web",
#   'the stories of john cheever',
#   'leviathan',
#   'three men in a boat',
#   'faerie tale',
#   'innocent blood',
#   'shattered mirror',
#   'around the world in eighty days'],
#  254: ["having our say: the delany sisters' first 100 years",
#   'factotum',
#   'black boy',
#   'sula',
#   'the last days',
#   'four past midnight',
#   'quicksand',
#   'ham on rye',
#   'song of solomon',
#   "the color of water: a black man's tribute to his white mother",
#   'the counterlife',
#   'demons',
#   'the prince of tides',
#   'cash',
#   'the tale of genji',
#   'suffer the children',
#   'insomnia',
#   'divine',
#   'eva luna',
#   'the group',
#   'killing rage: ending racism',
#   'midnight in the garden of good and evil',
#   'the capricorn stone',
#   'phantoms',
#   'the bad place',
#   'the color purple',
#   "world's fair",
#   'lives of girls and women',
#   'mother night',
#   'human croquet',
#   'birds of america',
#   'hand to mouth: a chronicle of early failure',
#   'the basketball diaries',
#   'angels',
#   'katherine',
#   'when we were orphans',
#   'a confederacy of dunces',
#   'a yellow raft in blue water',
#   'bliss',
#   'the greatest generation',
#   'native son',
#   'the heart is a lonely hunter',
#   'self',
#   'after dark',
#   'the buddha of suburbia',
#   'all the names',
#   'andrew carnegie',
#   'one door away from heaven',
#   'black like me',
#   'the blackwater lightship'],
#  256: ['golden urchin',
#   'the glass lake',
#   'the oath',
#   'blessings',
#   'fall on your knees',
#   "the handmaid's tale",
#   'wyrms',
#   'summer of my german soldier',
#   'leviathan',
#   'stardust',
#   "lucifer's shadow",
#   'dandelion wine',
#   'a year in provence',
#   'prodigal summer',
#   'public secrets',
#   'the man from st. petersburg',
#   'all quiet on the western front',
#   'the gift of asher lev',
#   'the soloist',
#   'can you keep a secret?',
#   'outlander',
#   'exquisite corpse',
#   'frost',
#   'strawberry girl',
#   'northern lights',
#   'phantoms',
#   'summer crossing',
#   'lives of girls and women',
#   'the rule of four',
#   'the greatest generation',
#   'birds of america',
#   'a pale view of hills',
#   'nothing lasts forever',
#   'the god of small things',
#   'beloved',
#   "sunny chandler's return",
#   'the ice storm',
#   'chronicle of a death foretold',
#   'mother of pearl',
#   'insomnia',
#   "the moor's last sigh",
#   'tar baby',
#   'the feast of all saints',
#   'homicide: a year on the killing streets',
#   'the woman in white',
#   'enchantment',
#   'echo',
#   'tara road',
#   'ghost story',
#   'romeo and juliet'],
#  387: ['alice in wonderland',
#   "alice's adventures in wonderland",
#   'wanted!',
#   'as she climbed across the table',
#   'to have and to hold',
#   'a map of the world',
#   'this is the way the world ends',
#   'the glass bead game',
#   'brazil',
#   'lives of girls and women',
#   'the red queen: sex and the evolution of human nature',
#   "mr. sammler's planet",
#   "charlotte's web",
#   'the eight',
#   'the hobbit',
#   'the eyes of the dragon',
#   'the design of everyday things',
#   'the tale of peter rabbit',
#   'the door in the hedge',
#   'the aleph and other stories',
#   'the metamorphosis and other stories',
#   'and to think that i saw it on mulberry street',
#   'relativity: the special and the general theory',
#   'selected non-fictions',
#   'the autobiography of alice b. toklas',
#   'a home at the end of the world',
#   'cujo',
#   'turtle moon',
#   'a fairly honourable defeat',
#   'nerve',
#   'boy meets boy',
#   'the probable future',
#   'carrie',
#   'harvesting the heart',
#   'the flanders panel',
#   'the night of wishes',
#   'cradle to cradle: remaking the way we make things',
#   'mary queen of scots',
#   'the monster at the end of this book',
#   'just so stories',
#   'i never promised you a rose garden',
#   'the damnation game',
#   'bridge to terabithia',
#   'the epic of gilgamesh',
#   'paris to the moon',
#   'perfect match',
#   'nineteen eighty-four',
#   'the rose and the beast: fairy tales retold',
#   'year of wonders',
#   'sing down the moon'],
#  388: ['the lost continent: travels in small town america',
#   "savage inequalities: children in america's schools",
#   'my year of meats',
#   'money',
#   'a quiver full of arrows',
#   'beowulf: a new telling',
#   'birds of america',
#   'a patchwork planet',
#   "gerald's game",
#   'skinny legs and all',
#   'the monster at the end of this book',
#   'baltasar and blimunda',
#   'human croquet',
#   'the greatest generation',
#   'the brothers lionheart',
#   'exile',
#   'herzog',
#   'the master',
#   'harvesting the heart',
#   'written on the body',
#   'as the crow flies',
#   'breathing lessons',
#   'round ireland with a fridge',
#   'shadow fires',
#   'man walks into a room',
#   'moo',
#   'cold mountain',
#   'syrup',
#   'boy meets boy',
#   'message in a bottle',
#   'the fourth hand',
#   'the milagro beanfield war',
#   'people of the lie: the hope for healing human evil',
#   'the corrections',
#   'across the river and into the trees',
#   'sense and sensibility',
#   'dreamcatcher',
#   'a multitude of sins',
#   'out of this world',
#   'the spell',
#   'emotional intelligence: why it can matter more than iq',
#   'sideways',
#   'identity',
#   'pippi in the south seas',
#   'congo',
#   'a frolic of his own',
#   'see how they run',
#   'p.s. your cat is dead',
#   "you can't go home again",
#   'pippi goes on board'],
#  413: ['scarlet feather',
#   'silas marner',
#   'falling angel',
#   'swan song',
#   'the scarlet pimpernel',
#   'de profundis',
#   'here is new york',
#   'howards end',
#   'confessions of an ugly stepsister',
#   'the power broker: robert moses and the fall of new york',
#   'message in a bottle',
#   'the crucible',
#   'the stories of john cheever',
#   "suzanne's diary for nicholas",
#   'the door in the hedge',
#   'follow your heart',
#   'roverandom',
#   'the winthrop woman',
#   'crime and punishment',
#   'little women',
#   'the unabridged journals of sylvia plath',
#   'native son',
#   'devilish',
#   'the jungle',
#   'sexing the cherry',
#   'the serpent and the rainbow',
#   'acts of faith',
#   'gone with the wind',
#   'a god in ruins',
#   'katherine',
#   'the greenlanders',
#   'hunger',
#   'she came to stay',
#   'you can never go home again',
#   'the far pavilions',
#   'the letters of j.r.r. tolkien',
#   'not without my daughter',
#   'julius caesar',
#   'demons',
#   'perfect match',
#   'relativity: the special and the general theory',
#   "all the king's men",
#   'paris to the moon',
#   'the great gatsby',
#   'narcissus and goldmund',
#   'the child in time',
#   'neverwhere',
#   'the railway children',
#   'birds of america',
#   'if beale street could talk'],
#  493: ['american psycho',
#   'firefly summer',
#   "in search of captain zero: a surfer's road trip beyond the end of the road",
#   'thanksgiving',
#   'the firm',
#   'changeling',
#   'a frolic of his own',
#   'the capricorn stone',
#   'the street lawyer',
#   'the pigeon',
#   'the god of small things',
#   'the king of torts',
#   'northern lights',
#   'perfume: the story of a murderer',
#   'the year of the death of ricardo reis',
#   'the soloist',
#   'the eyes of darkness',
#   'thus spoke zarathustra',
#   'the testament',
#   'mystic river',
#   'the assault',
#   'death of a salesman',
#   "if on a winter's night a traveler",
#   'the brethren',
#   'the railway children',
#   'andrew carnegie',
#   'the fall of berlin 1945',
#   'tamsin',
#   'narcissus and goldmund',
#   'great expectations',
#   'the jester',
#   'sideways',
#   'haunted',
#   'different seasons',
#   'cold mountain',
#   'the untouchable',
#   'tuck everlasting',
#   'the denial of death',
#   'prophet',
#   'public secrets',
#   'the dying animal',
#   'picture perfect',
#   'a different mirror: a history of multicultural america',
#   "lucifer's shadow",
#   'holy the firm',
#   'a walk to remember',
#   'the door in the hedge',
#   'age of iron',
#   'the five dysfunctions of a team: a leadership fable',
#   'a fine balance'],
#  500: ["spindle's end",
#   'deerskin',
#   'a little princess',
#   'enchantment',
#   'saving faith',
#   'swan song',
#   'the far pavilions',
#   'open secrets',
#   'gift from the sea',
#   'word of honor',
#   'the probable future',
#   'chronicle of a death foretold',
#   'the dream cycle of h.p. lovecraft: dreams of terror and death',
#   'a fine balance',
#   'assumed identity',
#   'demian',
#   'the princess bride',
#   'birds of america',
#   'the rings of saturn',
#   'the delta star',
#   'the unconsoled',
#   'east of eden',
#   'the inheritors',
#   'theater shoes',
#   'avalon',
#   'the silmarillion',
#   'the capricorn stone',
#   'the glass lake',
#   'v.',
#   'the rule of four',
#   'nights in rodanthe',
#   'silent spring',
#   'the music of chance',
#   'the king of torts',
#   'the diviners',
#   'the tale of the flopsy bunnies',
#   'the count of monte cristo',
#   'pop goes the weasel',
#   'the door to december',
#   'americana',
#   'oliver twist',
#   'the homecoming',
#   'the supernaturalist',
#   'the moon is a harsh mistress',
#   'the bluest eye',
#   'plain truth',
#   'frost',
#   'open house',
#   'a kiss before dying',
#   'the samurai'],
#  507: ['the blackwater lightship',
#   'bliss',
#   'a yellow raft in blue water',
#   'black boy',
#   "the color of water: a black man's tribute to his white mother",
#   'quicksand',
#   'sula',
#   'divine',
#   'the house of mirth',
#   'the color purple',
#   'mother of pearl',
#   "having our say: the delany sisters' first 100 years",
#   'tar baby',
#   'lives of girls and women',
#   'killing rage: ending racism',
#   'the prince of tides',
#   'five quarters of the orange',
#   'native son',
#   'bel canto',
#   'housekeeping',
#   'the heart is a lonely hunter',
#   'the eyes of darkness',
#   'the oath',
#   'katherine',
#   'harvesting the heart',
#   'the black tulip',
#   'little women',
#   'the makioka sisters',
#   'the changeling sea',
#   'age of iron',
#   'black beauty',
#   'dandelion wine',
#   'a bend in the road',
#   'fall on your knees',
#   'black like me',
#   'where we stand: class matters',
#   'sons and lovers',
#   'the moon is down',
#   'nights in rodanthe',
#   'wise child',
#   'song of solomon',
#   'the celestine prophecy',
#   'midnight in the garden of good and evil',
#   "prisoner's dilemma",
#   'birds of america',
#   'the calvin and hobbes tenth anniversary book',
#   'tuck everlasting',
#   'blindness',
#   'the guardian',
#   'eden close'],
#  595: ['the unicorn',
#   "i'll be seeing you",
#   'three weeks with my brother',
#   'message in a bottle',
#   'nothing lasts forever',
#   'nights in rodanthe',
#   'the art of loving',
#   'boy meets boy',
#   'the magus',
#   'job: a comedy of justice',
#   'all about love: new visions',
#   'saving faith',
#   'art and beauty in the middle ages',
#   'the four loves',
#   'forever . . .',
#   "the children's homer: the adventures of odysseus and the tale of troy",
#   "suzanne's diary for nicholas",
#   'a walk to remember',
#   'the mysterious island',
#   'what dreams may come',
#   'by the river piedra i sat down and wept',
#   'a quiver full of arrows',
#   'traveling mercies: some thoughts on faith',
#   'lightning',
#   'the greatest generation',
#   'to sail beyond the sunset',
#   'the guardian',
#   "boy's life",
#   'little women',
#   'paint it black',
#   'sense and sensibility',
#   'open house',
#   'cradle and all',
#   'immortality',
#   'jitterbug perfume',
#   'illusions: the adventures of a reluctant messiah',
#   'beauty and the beast',
#   'love letters',
#   'mother of pearl',
#   'public secrets',
#   'laughable loves',
#   'coraline',
#   'first love',
#   'rain of gold',
#   'a bend in the road',
#   'assumed identity',
#   'the house of the spirits',
#   'a prayer for owen meany',
#   'the door to december',
#   'divine'],
#  638: ['three weeks with my brother',
#   'the magus',
#   'boy meets boy',
#   'all about love: new visions',
#   'a christmas carol',
#   'the art of loving',
#   'public secrets',
#   'first love',
#   'a christmas memory',
#   'open house',
#   'the stories of john cheever',
#   'the master',
#   'follow your heart',
#   'forever . . .',
#   'immortality',
#   'out of this world',
#   'plain truth',
#   'a tree grows in brooklyn',
#   'harvesting the heart',
#   'the four loves',
#   'if beale street could talk',
#   'the corrections',
#   'the house of the spirits',
#   'lives of girls and women',
#   'danny the champion of the world',
#   'family matters',
#   'the sea',
#   'northern lights',
#   'beauty and the beast',
#   'the rule of four',
#   'mother of pearl',
#   'the door to december',
#   'amnesia moon',
#   'to sail beyond the sunset',
#   'the stories of vladimir nabokov',
#   'the age of grief',
#   'the god of small things',
#   'less than zero',
#   'the greatest generation',
#   "you can't go home again",
#   'romeo and juliet',
#   'the other boleyn girl',
#   'here is new york',
#   'to have and to hold',
#   'after the plague: and other stories',
#   'stinger',
#   'joy in the morning',
#   'no place like home',
#   'birds of america',
#   'acts of faith'],
#  651: ['victoria',
#   'the wall',
#   'the music of chance',
#   'the oath',
#   'word of honor',
#   'the fourth hand',
#   'american psycho',
#   'phantoms',
#   'the stone diaries',
#   'the thorn birds',
#   'the kindness of strangers',
#   'age of iron',
#   'northern lights',
#   'the celestine prophecy',
#   'birds of america',
#   'a painted house',
#   'falconer',
#   'summerland',
#   'insomnia',
#   'the lost continent: travels in small town america',
#   'mandy',
#   'echoes',
#   'the gambler',
#   "morgan's run",
#   'the town',
#   'blackberry wine',
#   'amnesia moon',
#   'the physics of star trek',
#   'housekeeping',
#   'the brethren',
#   'the reluctant reformer',
#   'outlander',
#   'women',
#   'ludwig wittgenstein: the duty of genius',
#   'neverwhere',
#   'follow your heart',
#   'a year in provence',
#   'the milagro beanfield war',
#   'snow',
#   '3rd degree',
#   'the moon is down',
#   'different seasons',
#   'mao ii',
#   'baltasar and blimunda',
#   "lucifer's shadow",
#   'coraline',
#   'beloved',
#   'roughing it',
#   "liar's poker",
#   'the nose'],
#  685: ['the gods themselves',
#   'stranger in a strange land',
#   'year zero',
#   "wild at heart: discovering the secret of a man's soul",
#   'journey',
#   'thirst',
#   'shadows',
#   'falling angel',
#   'famous last words',
#   'bloodlines',
#   'insomnia',
#   'tuf voyaging',
#   'wyrms',
#   "world's end",
#   'different seasons',
#   'ghostwritten',
#   'old school',
#   'tales of pirx the pilot',
#   'enchantress from the stars',
#   'the shining',
#   'riddley walker',
#   'word of honor',
#   'this alien shore',
#   'midnight predator',
#   'after dark',
#   'carrie',
#   "the executioner's song",
#   'the hotel new hampshire',
#   'the demon-haunted world: science as a candle in the dark',
#   'the last unicorn',
#   'the ground beneath her feet',
#   'lord of light',
#   'skeleton crew',
#   'the transition of h. p. lovecraft: the road to madness',
#   'hideaway',
#   'the art of war',
#   "the handmaid's tale",
#   'the gospel according to jesus christ',
#   'the child in time',
#   'the manhattan hunt club',
#   'a short history of decay',
#   'total eclipse',
#   'the blank slate: the modern denial of human nature',
#   'baudolino',
#   "man's search for meaning",
#   'human croquet',
#   'outlander',
#   "my sister's keeper",
#   'everyman',
#   'the fall of a sparrow'],
#  735: ['the alibi',
#   'a river runs through it',
#   'ricochet',
#   'the girl in a swing',
#   'how to enjoy your life and your job',
#   'the client',
#   'choke',
#   'the hobbit',
#   'birds of america',
#   'the wise woman',
#   'public secrets',
#   'tourist season',
#   'open house',
#   "angela's ashes",
#   'mr. maybe',
#   'shattered',
#   'the delta star',
#   'strata',
#   "one flew over the cuckoo's nest",
#   'youngblood hawke',
#   'the celestine prophecy',
#   'kingdom come',
#   'less than zero',
#   'franny and zooey',
#   'atlas shrugged',
#   'cloudsplitter',
#   "the time traveler's wife",
#   'four past midnight',
#   'arcadia',
#   'picture perfect',
#   'the master',
#   'mao ii',
#   'the falls',
#   'their eyes were watching god',
#   'p.s. your cat is dead',
#   'mine',
#   'fury',
#   "the dirt: confessions of the world's most notorious rock band",
#   'battle cry',
#   'a single man',
#   'see how they run',
#   'mary queen of scots',
#   'the red notebook: true stories',
#   'a virtuous woman',
#   'jurassic park',
#   'you belong to me',
#   'the unconsoled',
#   'the woman in white',
#   'a heartbreaking work of staggering genius',
#   'saving faith'],
#  746: ['just so stories',
#   'the great gatsby',
#   'mother night',
#   'suffer the children',
#   'demian',
#   'absolutely normal chaos',
#   'watership down',
#   'the death of ivan ilych and other stories',
#   'far from the madding crowd',
#   'goodnight moon',
#   'in the forests of the night',
#   'nothing lasts forever',
#   'island',
#   'from the corner of his eye',
#   'the outsiders',
#   'running with scissors',
#   'the time machine',
#   'demons',
#   'the alchemist',
#   'for whom the bell tolls',
#   'bad dreams',
#   'velocity',
#   'island of the blue dolphins',
#   'the mysterious island',
#   'into the wild',
#   'the moviegoer',
#   'the jungle',
#   'the mermaids singing',
#   'roughing it',
#   'the tipping point: how little things can make a big difference',
#   'the annotated lolita',
#   'kiss',
#   "the moor's last sigh",
#   'danse macabre',
#   'autobiography of a yogi',
#   'the outlaws of sherwood',
#   'pride and prejudice',
#   'the great divorce',
#   'the long road home',
#   'the 500 hats of bartholomew cubbins',
#   'in the lake of the woods',
#   'travels with charley: in search of america',
#   'the red notebook: true stories',
#   'the tempest',
#   'in a sunburned country',
#   'you can never go home again',
#   'holy the firm',
#   'hawaii',
#   'here is new york',
#   'the house on mango street'],
#  763: ['the waste land',
#   'dracula',
#   'the jungle',
#   'the sound and the fury',
#   'julius caesar',
#   'the tempest',
#   'the poems',
#   'clouds',
#   'the great gatsby',
#   'the annotated lolita',
#   'a brief history of time',
#   'in the lake of the woods',
#   'richard iii',
#   'battlefield of the mind: winning the battle in your mind',
#   'the fountains of paradise',
#   'the golden notebook',
#   'collected poems',
#   'the woman in white',
#   'five children and it',
#   'the dream of scipio',
#   'the master and margarita',
#   'great expectations',
#   'sense and sensibility',
#   'the tale of genji',
#   'selected poetry',
#   'ficciones',
#   'adventures of huckleberry finn',
#   'agnes grey',
#   'just so stories',
#   'mansfield park',
#   'the gambler',
#   'p.s. your cat is dead',
#   'demons',
#   'the marriage of heaven and hell',
#   'as i lay dying',
#   'nothing lasts forever',
#   'a clockwork orange',
#   'the second sex',
#   'the source',
#   'demian',
#   'a little princess',
#   'the hobbit',
#   'finnegans wake',
#   'marketing warfare',
#   'sir gawain and the green knight',
#   "charlotte's web",
#   "basic economics: a citizen's guide to the economy",
#   'the sheltering sky',
#   'the screwtape letters',
#   'falling angel'],
#  769: ['the art of loving',
#   'immortality',
#   'the four loves',
#   'all about love: new visions',
#   'the art of the novel',
#   'ferdydurke',
#   'katherine',
#   'laughable loves',
#   'one hundred years of solitude',
#   'falling angels',
#   'riddley walker',
#   'doctor faustus',
#   'endymion',
#   'slowness',
#   'romeo and juliet',
#   'mine',
#   'hunger',
#   'outlander',
#   'the ground beneath her feet',
#   'open secrets',
#   'atlas shrugged',
#   "suzanne's diary for nicholas",
#   'birdsong',
#   'the far pavilions',
#   'for whom the bell tolls',
#   'the idiot',
#   'the stories of eva luna',
#   'pope joan',
#   'polgara the sorceress',
#   'mao ii',
#   'message in a bottle',
#   'the jane austen book club',
#   'a star called henry',
#   'light a penny candle',
#   'follow your heart',
#   'the falls',
#   'beauty',
#   'a single man',
#   'love poems',
#   'native son',
#   'orlando',
#   'age of iron',
#   'the man from st. petersburg',
#   'the periodic table',
#   'open house',
#   'the grapes of wrath',
#   'something happened',
#   'cradle and all',
#   'a short history of decay',
#   'a very long engagement'],
#  777: ['the secret garden',
#   'five children and it',
#   'goodnight moon',
#   'much ado about nothing',
#   "charlotte's web",
#   'deerskin',
#   "spindle's end",
#   'the railway children',
#   'little women',
#   'the annotated lolita',
#   'blink',
#   'the sea wolf',
#   'selected stories',
#   'the tale of the flopsy bunnies',
#   'cyrano de bergerac',
#   'coraline',
#   'the jungle',
#   'a tree grows in brooklyn',
#   'wuthering heights',
#   'wicked: the life and times of the wicked witch of the west',
#   'human croquet',
#   'the history of the siege of lisbon',
#   'romeo and juliet',
#   'enchantment',
#   'the woman in white',
#   'the tempest',
#   'maya',
#   'white teeth',
#   'as you like it',
#   'the marriage of heaven and hell',
#   'the capricorn stone',
#   'witness',
#   'an ideal husband',
#   'alice in wonderland',
#   'the princess bride',
#   'the tale of peter rabbit',
#   'when the elephants dance',
#   'eugene onegin',
#   'one day in the life of ivan denisovich',
#   'the sound and the fury',
#   'confessions',
#   'the fountainhead',
#   'possession',
#   'islands in the stream',
#   'one hundred years of solitude',
#   'the cave',
#   'the jungle books',
#   'the magus',
#   'antigone',
#   'horton hatches the egg'],
#  805: ['the namesake',
#   'hawaii',
#   'a passage to india',
#   'the blackwater lightship',
#   'katherine',
#   'alice in wonderland',
#   'demon in my view',
#   'rage of angels',
#   'when the elephants dance',
#   'gone with the wind',
#   'harvesting the heart',
#   'the adolescent',
#   "suzanne's diary for nicholas",
#   'human croquet',
#   'eva luna',
#   'the far pavilions',
#   'narcissus and goldmund',
#   'the art of loving',
#   'maya',
#   'the catcher in the rye',
#   'summerland',
#   'house of the sleeping beauties and other stories',
#   'out of this world',
#   'the mambo kings play songs of love',
#   'black boy',
#   'birdsong',
#   'the moonstone',
#   'the collected stories of arthur c. clarke',
#   'mao ii',
#   'tortilla flat',
#   'the stories of john cheever',
#   'kinfolk',
#   'here is new york',
#   'a star called henry',
#   'the other boleyn girl',
#   'microserfs',
#   'angle of repose',
#   'written on the body',
#   "corelli's mandolin",
#   'follow your heart',
#   'little women',
#   'everyman',
#   'falling angels',
#   "there's no such place as far away",
#   'song of solomon',
#   'the ground beneath her feet',
#   'the rachel papers',
#   'the winthrop woman',
#   'the red notebook: true stories',
#   'running from safety: an adventure of the spirit'],
#  828: ['cosmos',
#   'an american childhood',
#   "bulfinch's mythology",
#   'blessings',
#   'arcadia',
#   'saving faith',
#   'journey',
#   'the amateur marriage',
#   'lord of light',
#   'dreamcatcher',
#   'the guns of august',
#   'longitude: the true story of a lone genius who solved the greatest scientific problem of his time',
#   'my year of meats',
#   'enchantress from the stars',
#   "the botany of desire: a plant's-eye view of the world",
#   'chimera',
#   'the mambo kings play songs of love',
#   'the greatest generation',
#   'joy in the morning',
#   'when we were orphans',
#   'brave new world',
#   'the cyberiad',
#   'house of leaves',
#   'journey to ixtlan',
#   'deception point',
#   'the talisman',
#   'brazil',
#   'the wise woman',
#   'the grapes of wrath',
#   'still life with woodpecker',
#   'traveling mercies: some thoughts on faith',
#   'art and beauty in the middle ages',
#   "man's search for meaning",
#   'relativity: the special and the general theory',
#   'winterdance: the fine madness of running the iditarod',
#   'four past midnight',
#   'in the lake of the woods',
#   'dubliners',
#   'howards end',
#   'to kill a mockingbird',
#   'death of a salesman',
#   'the gods themselves',
#   'the complete short stories',
#   'year zero',
#   'house of the sleeping beauties and other stories',
#   'the stories of john cheever',
#   'mythology',
#   'annals of the former world',
#   'the age of grief',
#   'fire from within'],
#  882: ['the stories of eva luna',
#   'the greatest generation',
#   'when the elephants dance',
#   'follow your heart',
#   'baltasar and blimunda',
#   'the fall of a sparrow',
#   'man walks into a room',
#   'in the heart of the sea: the tragedy of the whaleship essex',
#   'the house of the spirits',
#   'the art of loving',
#   'message in a bottle',
#   'the ground beneath her feet',
#   'human croquet',
#   'the mermaids singing',
#   'a pale view of hills',
#   'age of iron',
#   'paris to the moon',
#   'the silmarillion',
#   'all families are psychotic',
#   "boy's life",
#   'the inheritors',
#   'exile',
#   'blessings',
#   'the falls',
#   'when the emperor was divine',
#   'beach music',
#   'longitude: the true story of a lone genius who solved the greatest scientific problem of his time',
#   'island of the blue dolphins',
#   "anne's house of dreams",
#   'the corrections',
#   'the makioka sisters',
#   "suzanne's diary for nicholas",
#   'the secret diary of anne boleyn',
#   'fugitive pieces',
#   'the portrait of a lady',
#   'anna karenina',
#   'the wanderer',
#   'no ordinary time: franklin and eleanor roosevelt: the home front in world war ii',
#   'the five people you meet in heaven',
#   'the red notebook: true stories',
#   'just above my head',
#   'a multitude of sins',
#   'out of this world',
#   'paris 1919: six months that changed the world',
#   'the great gatsby',
#   'daughter of fortune',
#   'one door away from heaven',
#   'harvesting the heart',
#   'andrew carnegie',
#   'the pigeon'],
#  903: ['tales of ordinary madness',
#   'factotum',
#   'you get so alone at times that it just makes sense',
#   'women',
#   'less than zero',
#   'a star called henry',
#   'sideways',
#   'a portrait of the artist as a young man',
#   'white oleander',
#   'the adolescent',
#   'pastwatch: the redemption of christopher columbus',
#   'the ice storm',
#   'slaughterhouse-five',
#   'light in august',
#   'the grapes of wrath',
#   'thumbsucker',
#   'self',
#   "she's come undone",
#   'a tree grows in brooklyn',
#   'youth',
#   'darkness visible: a memoir of madness',
#   'the basketball diaries',
#   'coin locker babies',
#   'tropic of cancer',
#   'there are no children here: the story of two boys growing up in the other america',
#   'fierce invalids home from hot climates',
#   'a separate peace',
#   'money',
#   'the noonday demon: an atlas of depression',
#   'autobiography of a yogi',
#   'old school',
#   'doctor faustus',
#   'different seasons',
#   "the time traveler's wife",
#   'the catcher in the rye',
#   'by the river piedra i sat down and wept',
#   'pope joan',
#   'the choirboys',
#   'the tale of genji',
#   'election',
#   'the greatest generation',
#   'the dark half',
#   'savage beauty: the life of edna st. vincent millay',
#   'fell',
#   'the ground beneath her feet',
#   'the air-conditioned nightmare',
#   'parliament of whores: a lone humorist attempts to explain the entire u.s. government',
#   'the partly cloudy patriot',
#   "we'll meet again",
#   'henry v'],
#  929: ['the heart is a lonely hunter',
#   'the prophet',
#   'black boy',
#   'black like me',
#   'the secret life of bees',
#   'the house of the spirits',
#   'invisible man',
#   'black beauty',
#   'gone with the wind',
#   'quicksand',
#   'the railway children',
#   'the richest man in babylon',
#   'the passion',
#   'fell',
#   "savage inequalities: children in america's schools",
#   'the feminine mystique',
#   'wild swans: three daughters of china',
#   'horton hatches the egg',
#   "having our say: the delany sisters' first 100 years",
#   'philosophy for dummies',
#   'native son',
#   'the trial',
#   'to kill a mockingbird',
#   'going native',
#   "there's no such place as far away",
#   'the twelve dancing princesses',
#   'come away my beloved',
#   'the god of small things',
#   'cold mountain',
#   'the house on mango street',
#   'the screwtape letters',
#   'the polar express',
#   'american gods',
#   'how to make love like a porn star: a cautionary tale',
#   "charlotte's web",
#   'goodnight moon',
#   'till we have faces: a myth retold',
#   'the tale of the flopsy bunnies',
#   'a tree grows in brooklyn',
#   'follow your heart',
#   'the awakening',
#   'wise child',
#   'the power and the glory',
#   'the very hungry caterpillar',
#   'cane river',
#   'a kiss before dying',
#   'a brief history of time',
#   'the aleph and other stories',
#   'songmaster',
#   "my sister's keeper"],
#  965: ['fast food nation: the dark side of the all-american meal',
#   'strawberry girl',
#   "bill bryson's african diary",
#   'where the heart is',
#   'the shining',
#   'money',
#   'diary',
#   'watership down',
#   'amerika',
#   'factotum',
#   'the guns of august',
#   'no ordinary time: franklin and eleanor roosevelt: the home front in world war ii',
#   'hawaii',
#   'women',
#   'haunted',
#   'northern lights',
#   'strange pilgrims',
#   'cities of the red night',
#   'island of the blue dolphins',
#   'the rainmaker',
#   'the ground beneath her feet',
#   'collected short stories',
#   'a multitude of sins',
#   'the monster at the end of this book',
#   'dogeaters',
#   'one door away from heaven',
#   "one flew over the cuckoo's nest",
#   'kinfolk',
#   'of mice and men',
#   'horse heaven',
#   'americana',
#   'the grapes of wrath',
#   'midnight predator',
#   'last man standing',
#   "liar's poker",
#   'trump: the art of the deal',
#   'family matters',
#   'travels with charley: in search of america',
#   'shattered',
#   'getting things done: the art of stress-free productivity',
#   'up in the air',
#   'house of leaves',
#   'angle of repose',
#   'dubliners',
#   'the last american man',
#   'the flame trees of thika: memories of an african childhood',
#   'mythology',
#   'after dark',
#   'pet sematary',
#   'year zero'],
#  1022: ['seven plays',
#   'traveling mercies: some thoughts on faith',
#   'open house',
#   'harvesting the heart',
#   'the westing game',
#   'all through the night',
#   'persuasion',
#   'fathers and sons',
#   'women',
#   "anne's house of dreams",
#   'the mill on the floss',
#   'in the heart of the sea: the tragedy of the whaleship essex',
#   'four past midnight',
#   'herzog',
#   'the changeling sea',
#   'the curious incident of the dog in the night-time',
#   'the maltese falcon',
#   'the god of small things',
#   'the golden notebook',
#   "the color of water: a black man's tribute to his white mother",
#   'the monster at the end of this book',
#   'practical ethics',
#   'anne of avonlea',
#   'gift from the sea',
#   "charlotte's web",
#   "world's fair",
#   'anne of green gables',
#   'the wanderer',
#   'the boomer bible',
#   'she came to stay',
#   'cry to heaven',
#   'kinfolk',
#   'a friend of the earth',
#   "james herriot's dog stories",
#   'first love',
#   'breathing lessons',
#   "savage inequalities: children in america's schools",
#   'the power of myth',
#   'atonement',
#   'i capture the castle',
#   'the birth of venus',
#   'the secret diary of anne boleyn',
#   'small wonder',
#   'gifted hands: the ben carson story',
#   'by the river piedra i sat down and wept',
#   'lives of girls and women',
#   'tom jones',
#   'birds of america',
#   'the promise',
#   'marjorie morningstar'],
#  1025: ['the color purple',
#   'a brief history of time',
#   'philosophy for dummies',
#   'to kill a mockingbird',
#   'autobiography of a yogi',
#   'lost in the funhouse',
#   'the complete short stories',
#   'all i really need to know i learned in kindergarten',
#   "einstein's dreams",
#   'the fifth mountain',
#   'the catcher in the rye',
#   'the art of loving',
#   "beauty's punishment",
#   'fiasco',
#   'follow your heart',
#   "savage inequalities: children in america's schools",
#   'thus spoke zarathustra',
#   'the very hungry caterpillar',
#   'light a penny candle',
#   'the road to serfdom',
#   'written on the body',
#   'money',
#   'the brothers karamazov',
#   'the feminine mystique',
#   'white oleander',
#   'escape from freedom',
#   'pippi goes on board',
#   "wouldn't take nothing for my journey now",
#   'gift from the sea',
#   'the polar express',
#   'on a pale horse',
#   'by the river piedra i sat down and wept',
#   'the brothers lionheart',
#   'battlefield of the mind: winning the battle in your mind',
#   'the age of grief',
#   'the secret garden',
#   'slouching towards bethlehem',
#   'falconer',
#   'beauty',
#   'exit to eden',
#   'the master and margarita',
#   'collected poems',
#   'the four loves',
#   'wild swans: three daughters of china',
#   'the richest man in babylon',
#   'black beauty',
#   'the marriage of heaven and hell',
#   'the age of reason',
#   'stranger in a strange land',
#   "the time traveler's wife"],
#  1032: ['follow your heart',
#   'an american childhood',
#   'three tales',
#   "savage inequalities: children in america's schools",
#   'journey to the end of the night',
#   'hiroshima',
#   'a tree grows in brooklyn',
#   'the grapes of wrath',
#   'the amateur marriage',
#   'the prophet',
#   'black boy',
#   'the art of loving',
#   'the moviegoer',
#   'the house on mango street',
#   'wild swans: three daughters of china',
#   'autobiography of a yogi',
#   'endymion',
#   'the rainmaker',
#   'the secret garden',
#   'shopgirl',
#   'the color purple',
#   'different seasons',
#   'a portrait of the artist as a young man',
#   'how to win friends and influence people',
#   'youngblood hawke',
#   'the feminine mystique',
#   'ferdydurke',
#   'all about love: new visions',
#   'black elk speaks: being the life story of a holy man of the oglala sioux',
#   'katherine',
#   "angela's ashes",
#   'never let me go',
#   'sula',
#   'arctic dreams',
#   'cancer ward',
#   'of mice and men',
#   'the adolescent',
#   'main street',
#   'a personal matter',
#   "suzanne's diary for nicholas",
#   "boy's life",
#   'midnight in the garden of good and evil',
#   'a separate peace',
#   'out of this world',
#   'the untouchables',
#   'witness',
#   'the mambo kings play songs of love',
#   'the richest man in babylon',
#   'accordion crimes',
#   'dracula'],
#  1060: ['mr. murder',
#   "savage inequalities: children in america's schools",
#   'martin chuzzlewit',
#   'arrowsmith',
#   'muhammad: a biography of the prophet',
#   'about a boy',
#   'daughter of fortune',
#   'heat',
#   "the millionaire next door: the surprising secrets of america's wealthy",
#   'to kill a mockingbird',
#   'out of this world',
#   'four past midnight',
#   'my year of meats',
#   'the untouchable',
#   "winter's tale",
#   'crossing to safety',
#   'stormy weather',
#   'a brief history of time',
#   'dead souls',
#   'you get so alone at times that it just makes sense',
#   'black dogs',
#   'the railway children',
#   'main street',
#   'age of iron',
#   'the amateur marriage',
#   'just above my head',
#   'sisters',
#   'mortals',
#   'here i stand: a life of martin luther',
#   'three men in a boat',
#   'collected stories',
#   'democracy in america',
#   'follow your heart',
#   'absolutely normal chaos',
#   'color: a natural history of the palette',
#   'baltasar and blimunda',
#   'a patchwork planet',
#   'the spell',
#   'five children and it',
#   'the rachel papers',
#   'five quarters of the orange',
#   'pippi in the south seas',
#   'tales of ordinary madness',
#   'the fourth hand',
#   'youngblood hawke',
#   'tom jones',
#   'we the living',
#   'to sail beyond the sunset',
#   'evening class',
#   'the unbearable lightness of being'],
#  1075: ['the blackwater lightship',
#   'bliss',
#   'a yellow raft in blue water',
#   'black boy',
#   "the color of water: a black man's tribute to his white mother",
#   'quicksand',
#   'sula',
#   'divine',
#   'the house of mirth',
#   'the color purple',
#   'mother of pearl',
#   "having our say: the delany sisters' first 100 years",
#   'tar baby',
#   'lives of girls and women',
#   'killing rage: ending racism',
#   'the prince of tides',
#   'five quarters of the orange',
#   'native son',
#   'bel canto',
#   'housekeeping',
#   'the heart is a lonely hunter',
#   'the eyes of darkness',
#   'the oath',
#   'katherine',
#   'harvesting the heart',
#   'the black tulip',
#   'little women',
#   'the makioka sisters',
#   'the changeling sea',
#   'age of iron',
#   'black beauty',
#   'dandelion wine',
#   'a bend in the road',
#   'fall on your knees',
#   'black like me',
#   'where we stand: class matters',
#   'sons and lovers',
#   'the moon is down',
#   'nights in rodanthe',
#   'wise child',
#   'song of solomon',
#   'the celestine prophecy',
#   'midnight in the garden of good and evil',
#   "prisoner's dilemma",
#   'birds of america',
#   'the calvin and hobbes tenth anniversary book',
#   'tuck everlasting',
#   'blindness',
#   'the guardian',
#   'eden close'],
#  1083: ['lord of light',
#   'the lord of the rings',
#   'the letters of j.r.r. tolkien',
#   'the gods themselves',
#   "hart's hope",
#   'across the river and into the trees',
#   'the years of rice and salt',
#   'travels with charley: in search of america',
#   'the lorax',
# ...
#   'the enormous crocodile',
#   'the door into summer',
#   'the fourth hand',
#   'the heart of the matter',
#   'the autobiography of alice b. toklas',
#   "the time traveler's wife",
#   'a kiss before dying',
#   "when heaven and earth changed places: a vietnamese woman's journey from war to peace",
#   'last man standing',
#   'strangers on a train',
#   'the rule of four',
#   'velocity',
#   'on death and dying',
#   'sanctuary',
#   'the secret garden',
#   'lightning',
#   'all quiet on the western front',
#   'the birth of venus',
#   'ham on rye'],
#  28523: ['as you like it',
#   'the tempest',
#   'if beale street could talk',
#   'much ado about nothing',
#   'brazil',
#   'richard iii',
#   'clouds',
#   "world's fair",
#   'the real thing',
#   'an ideal husband',
#   'falling angels',
#   'the unbearable lightness of being',
#   'atlas shrugged',
#   'othello',
#   'wild swans: three daughters of china',
#   "suzanne's diary for nicholas",
#   'measure for measure',
#   'strawberry girl',
#   'cyrano de bergerac',
#   'demian',
#   "the winter's tale",
#   'the art of loving',
#   'by the river piedra i sat down and wept',
#   'joy in the morning',
#   'hamlet',
#   'across the river and into the trees',
#   'falling angel',
#   "lucifer's shadow",
#   'katherine',
#   "a midsummer night's dream",
#   'identity',
#   'henry v',
#   'one door away from heaven',
#   'innocent blood',
#   'sons and lovers',
#   'all about love: new visions',
#   "who's afraid of virginia woolf?",
#   'message in a bottle',
#   'the bad place',
#   'exquisite corpse',
#   'the house on mango street',
#   'house of sand and fog',
#   "einstein's dreams",
#   'a man of the people',
#   'thirst',
#   'journey',
#   'der richter und sein henker',
#   'cradle and all',
#   'a little princess',
#   'the greatest generation'],
#  28619: ['east of eden',
#   'the epic of gilgamesh',
#   'exit to eden',
#   'jazz',
#   'english passengers',
#   'parliament of whores: a lone humorist attempts to explain the entire u.s. government',
#   'andrew carnegie',
#   'journal of a novel: the east of eden letters',
#   "the millionaire next door: the surprising secrets of america's wealthy",
#   'snow',
#   'collected fictions',
#   'lives of girls and women',
#   'the changeling sea',
#   "you can't go home again",
#   'human croquet',
#   'by the river piedra i sat down and wept',
#   'exquisite corpse',
#   'chronicle of a death foretold',
#   'the soloist',
#   'the tale of the flopsy bunnies',
#   'the little friend',
#   'plain truth',
#   'the secret life of bees',
#   'the fall of a sparrow',
#   "in harm's way: the sinking of the uss indianapolis and the extraordinary story of its survivors",
#   'lightning',
#   'harvesting the heart',
#   'the pact',
#   "the color of water: a black man's tribute to his white mother",
#   'five quarters of the orange',
#   'in the lake of the woods',
#   "the midwife's tale",
#   'girlfriend in a coma',
#   'what the body remembers',
#   'the noonday demon: an atlas of depression',
#   'the return of the native',
#   'animal farm',
#   'breathing lessons',
#   'monster',
#   'here on earth',
#   'the diviners',
#   'the letters of j.r.r. tolkien',
#   'the other boleyn girl',
#   "angela's ashes",
#   'emma',
#   'love in the time of cholera',
#   'sula',
#   'no place like home',
#   'atonement',
#   'coraline'],
#  28634: ['cold mountain',
#   'carter beats the devil',
#   'see how they run',
#   'saving faith',
#   'the soloist',
#   'the eyes of darkness',
#   'prophet',
#   'ghost story',
#   'total control',
#   "lucifer's shadow",
#   'northern lights',
#   'homicide: a year on the killing streets',
#   'public secrets',
#   'a kiss before dying',
#   'you belong to me',
#   'feersum endjinn',
#   'different seasons',
#   'the oath',
#   'the rainmaker',
#   'changeling',
#   'insomnia',
#   'out',
#   'cradle and all',
#   'blessings',
#   "we'll meet again",
#   'the alibi',
#   'year zero',
#   'storm of the century: an original screenplay',
#   'nothing lasts forever',
#   'summer of my german soldier',
#   'open house',
#   'the rule of four',
#   'the girl in a swing',
#   'romeo and juliet',
#   'three weeks with my brother',
#   'birds of america',
#   'chronicle of a death foretold',
#   'anne of green gables',
#   'one door away from heaven',
#   'the hollow man',
#   'plain truth',
#   '3rd degree',
#   'golden urchin',
#   'gone south',
#   'all quiet on the western front',
#   'the man from st. petersburg',
#   'ricochet',
#   'like a velvet glove cast in iron',
#   'the glass lake',
#   'the greatest generation'],
#  28647: ['the big bad wolf',
#   'the alibi',
#   'pope joan',
#   'leviathan',
#   'my year of meats',
#   'slouching towards bethlehem',
#   'the autograph man',
#   'english passengers',
#   'a clockwork orange',
#   'the dark half',
#   'lolita',
#   'you belong to me',
#   'job: a comedy of justice',
#   'the wall',
#   'white oleander',
#   'poppy',
#   'eden',
#   'black like me',
#   'the rings of saturn',
#   'strangers on a train',
#   'first love',
#   'kingdom come',
#   'the black tulip',
#   'the bad place',
#   'enduring love',
#   'oliver twist',
#   'the spell',
#   'the diviners',
#   'sense and sensibility',
#   'zombie',
#   'no place like home',
#   'i capture the castle',
#   'the king of torts',
#   'dead sleep',
#   'burr',
#   'demon in my view',
#   'the pelican brief',
#   'ricochet',
#   'the adventures of sherlock holmes',
#   'saving faith',
#   '3rd degree',
#   'oscar wilde',
#   'annals of the former world',
#   'a very long engagement',
#   "fermat's enigma: the epic quest to solve the world's greatest mathematical problem",
#   'blink',
#   'tales of power',
#   'the guardian',
#   'the dispossessed',
#   'stardust'],
#  28663: ['to the lighthouse',
#   "who's afraid of virginia woolf?",
#   "a room of one's own",
#   'the jungle',
#   'the waste land',
#   'think and grow rich',
#   'the twits',
#   'orlando',
#   'the gun seller',
#   'silent spring',
#   'the i ching or book of changes',
#   'black dogs',
#   'a single man',
#   'a tale of two cities',
#   'the active side of infinity',
#   'the crimson petal and the white',
#   'the kissing hand',
#   'finnegans wake',
#   'under the volcano',
#   'julius caesar',
#   'the lorax',
#   'enduring love',
#   'adventures of huckleberry finn',
#   'nuns and soldiers',
#   'one hundred years of solitude',
#   'letters home',
#   'arrowsmith',
#   'the letters of j.r.r. tolkien',
#   'the unconsoled',
#   'a passage to india',
#   'rosencrantz and guildenstern are dead',
#   'sense and sensibility',
#   'battlefield of the mind: winning the battle in your mind',
#   'the collected stories of arthur c. clarke',
#   'dispatches',
#   'the secret diary of anne boleyn',
#   'lost in the funhouse',
#   'mama day',
#   'house of leaves',
#   'the source',
#   'lord jim',
#   'going to meet the man',
#   'parliament of whores: a lone humorist attempts to explain the entire u.s. government',
#   'seven plays',
#   'writing',
#   'the stone diaries',
#   'nine stories',
#   'wuthering heights',
#   "long day's journey into night",
#   'the complete stories'],
#  28666: ["beauty's punishment",
#   'beauty: a retelling of the story of beauty and the beast',
#   'rose daughter',
#   'black beauty',
#   'the rose and the beast: fairy tales retold',
#   'faerie tale',
#   'enchantment',
#   'kissing the witch: old tales in new skins',
#   'lost horizon',
#   'view with a grain of sand: selected poems',
#   "patty jane's house of curl",
#   'the silence of the lambs',
#   'the tolkien reader',
#   'across the river and into the trees',
#   'the flame trees of thika: memories of an african childhood',
#   'white oleander',
#   'an artist of the floating world',
#   'beauty and the beast',
#   'a river runs through it and other stories',
#   'jazz',
#   'the foundling',
#   'the prince of tides',
#   'the red queen: sex and the evolution of human nature',
#   'a patchwork planet',
#   'the door to december',
#   'the basketball diaries',
#   'the stories of vladimir nabokov',
#   'wide sargasso sea',
#   "if on a winter's night a traveler",
#   "spindle's end",
#   'under the net',
#   "savage inequalities: children in america's schools",
#   'the killer angels',
#   'house of the sleeping beauties and other stories',
#   'green hills of africa',
#   "the naked ape: a zoologist's study of the human animal",
#   'fiasco',
#   'the unbearable lightness of being',
#   'the lorax',
#   'the catcher in the rye',
#   'the lord god made them all',
#   'avalon',
#   'the greatest generation',
#   'slowness',
#   'ragtime',
#   'human croquet',
#   'crooked house',
#   'glamorama',
#   'pastwatch: the redemption of christopher columbus',
#   'marjorie morningstar'],
#  28680: ['what dreams may come',
#   'joy in the morning',
#   'an american childhood',
#   'spencerville',
#   'accordion crimes',
#   'an artist of the floating world',
#   'up country',
#   'much ado about nothing',
#   'charms for the easy life',
#   'the unicorn',
#   'she came to stay',
#   'the birth of venus',
#   'of love and other demons',
#   'the golden notebook',
#   'difficult conversations: how to discuss what matters most',
#   'the real thing',
#   'zombie',
#   'blackberry wine',
#   'the art of dreaming',
#   'marabou stork nightmares',
#   'a million little pieces',
#   'holy the firm',
#   "homer's daughter",
#   'exodus',
#   'the red notebook: true stories',
#   "james herriot's dog stories",
#   "savage inequalities: children in america's schools",
#   'practical ethics',
#   'heart songs and other stories',
#   'the greenlanders',
#   'brokeback mountain',
#   'the delta star',
#   'finnegans wake',
#   "charlotte's web",
#   'youngblood hawke',
#   'an instance of the fingerpost',
#   "one writer's beginnings",
#   'the counterlife',
#   'the rule of four',
#   'candy',
#   'out of this world',
#   'the shadow of the wind',
#   'nights in rodanthe',
#   'the body artist',
#   'the untouchable',
#   'james and the giant peach',
#   'a bend in the road',
#   'julius caesar',
#   'earthly powers',
#   'slammerkin'],
#  28705: ['exile',
#   'in cold blood',
#   'choke',
#   'under the net',
#   'baltasar and blimunda',
#   'feersum endjinn',
#   'the nonesuch',
#   'balzac and the little chinese seamstress',
#   'an instance of the fingerpost',
#   'leviathan',
#   'den of thieves',
#   'the collected stories of arthur c. clarke',
#   'the stories of vladimir nabokov',
#   'the client',
#   'phantoms',
#   'the wanderer',
#   'heat',
#   'the samurai',
#   "anil's ghost",
#   'the diviners',
#   'code complete',
#   'longitude: the true story of a lone genius who solved the greatest scientific problem of his time',
#   '1421: the year china discovered america',
#   'the power broker: robert moses and the fall of new york',
#   'going to meet the man',
#   'still life with woodpecker',
#   'tamsin',
#   'congo',
#   'middlesex',
#   'the eyes of darkness',
#   'the piano shop on the left bank: discovering a forgotten passion in a paris atelier',
#   "boy's life",
#   "the pilot's wife",
#   'innocent blood',
#   'famous last words',
#   'the code book: the science of secrecy from ancient egypt to quantum cryptography',
#   'bravo two zero',
#   'the dream of scipio',
#   'side effects',
#   'beach music',
#   'mutants: on genetic variety and the human body',
#   'slowness',
#   'runaway',
#   'mystic river',
#   'the birth of venus',
#   'theater shoes',
#   'the girl who loved tom gordon',
#   'civilization and its discontents',
#   'the hound of the baskervilles',
#   'dead sleep'],
#  28709: ['salem falls',
#   'the talisman',
#   'sideways',
#   'peter pan',
#   'the tale of peter rabbit',
#   "winter's tale",
#   'the brethren',
#   'a frolic of his own',
#   'desolation angels',
#   'white noise',
#   "the pilot's wife",
#   'the firm',
#   'the music of chance',
#   'beach music',
#   'the subterraneans',
#   'the call of the wild',
#   'my life as a man',
#   'on the road',
#   'perfect match',
#   'a dangerous fortune',
#   'lost',
#   'the house that jack built',
#   'money',
#   'the tolkien reader',
#   'our mutual friend',
#   'can you keep a secret?',
#   'the shining',
#   'holy the firm',
#   'book of dreams',
#   "all the king's men",
#   'circle of friends',
#   'into the wild',
#   'the outsider',
#   'a lesson before dying',
#   'animal liberation',
#   'the mambo kings play songs of love',
#   'the alchemist',
#   'the sea wolf',
#   'and to think that i saw it on mulberry street',
#   'blonde',
#   'filth',
#   'pope joan',
#   "a midsummer night's dream",
#   'enslaved by ducks',
#   'election',
#   'the partner',
#   'a year in provence',
#   'changeling',
#   'a virtuous woman',
#   'a streetcar named desire'],
#  28718: ['all quiet on the western front',
#   'boy meets boy',
#   'nights in rodanthe',
#   'she came to stay',
#   'the brothers k',
#   'the rule of four',
#   'the nose',
#   'sons and lovers',
#   'hand to mouth: a chronicle of early failure',
#   'chronicle of a death foretold',
#   'the autobiography of alice b. toklas',
#   'catch-22',
#   'misery',
#   "when heaven and earth changed places: a vietnamese woman's journey from war to peace",
#   'youngblood hawke',
#   'a separate peace',
#   'black and blue',
#   'my life',
#   'the complete plays',
#   'the green mile',
#   'the promise',
#   'up in the air',
#   'an artist of the floating world',
#   'the new york trilogy',
#   'the jester',
#   'one door away from heaven',
#   'the screwtape letters',
#   'the mandarins',
#   'angels',
#   'the music of chance',
#   'perfect match',
#   'babbitt',
#   'where the wild things are',
#   'autobiography of a yogi',
#   'of love and shadows',
#   'critique of pure reason',
#   'the journey to the east',
#   'a tree grows in brooklyn',
#   'when we were orphans',
#   'kinfolk',
#   'the stone diaries',
#   'no place like home',
#   'the ethics of ambiguity',
#   'dispatches',
#   'insomnia',
#   "bill bryson's african diary",
#   'deadlock',
#   "einstein's dreams",
#   'the quiet american',
#   'immortality'],
#  28735: ['cash',
#   'the call of the wild',
#   'island of the blue dolphins',
#   'for whom the bell tolls',
#   'a civil action',
#   'beauty',
#   'immortality',
#   'alaska',
#   'watership down',
#   'the counterlife',
#   'the feast of all saints',
#   'salem falls',
#   'of mice and men',
#   'z for zachariah',
#   'lord of the flies',
#   'el coronel no tiene quien le escriba',
#   'velocity',
#   'east wind: west wind',
#   'the tolkien reader',
#   'rabia',
#   'demian',
#   'caravans',
#   'paris 1919: six months that changed the world',
#   'el nombre de la rosa',
#   'the greenlanders',
#   'a river runs through it and other stories',
#   'fell',
#   'east of eden',
#   'coming into the country',
#   'a very long engagement',
#   'walking with the wind: a memoir of the movement',
#   'the breaker',
#   'mother night',
#   'the greatest generation',
#   'balzac and the little chinese seamstress',
#   'the eyes of darkness',
#   'gone for soldiers: a novel of the mexican war',
#   'how green was my valley',
#   'american gods',
#   'como agua para chocolate',
#   'drop city',
#   'prophet',
#   'paradise lost and paradise regained',
#   'money',
#   'the i ching or book of changes',
#   'just so stories',
#   'a frolic of his own',
#   "in search of captain zero: a surfer's road trip beyond the end of the road",
#   "beauty's punishment",
#   'el retrato de dorian gray'],
#  28763: ['the twits',
#   'the greatest generation',
#   'the magic finger',
#   'never let me go',
#   'the inheritors',
#   'they cage the animals at night',
#   'the giggler treatment',
#   "brian's winter",
#   'daughter of fortune',
#   'bad dreams',
#   "charlotte's web",
#   'when we were orphans',
#   'theater shoes',
#   'death of a salesman',
#   'the good fairies of new york',
#   'reflex',
#   'mine',
#   'the guns of august',
#   "winter's tale",
#   'storm of the century: an original screenplay',
#   'if chins could kill: confessions of a b movie actor',
#   'living to tell the tale',
#   'breathing lessons',
#   'how to win friends and influence people',
#   'faerie tale',
#   'a quiver full of arrows',
#   'little women',
#   "the dirt: confessions of the world's most notorious rock band",
#   "man's search for meaning",
#   'no ordinary time: franklin and eleanor roosevelt: the home front in world war ii',
#   'high fidelity',
#   'the monster at the end of this book',
#   "the millionaire next door: the surprising secrets of america's wealthy",
#   'chronicle of a death foretold',
#   'the assistant',
#   'fury',
#   'the power of now: a guide to spiritual enlightenment',
#   'sisters',
#   'a bend in the road',
#   'insomnia',
#   'the celestine prophecy',
#   'the moon is down',
#   'the princess bride',
#   'darkfall',
#   'fast food nation: the dark side of the all-american meal',
#   'leviathan',
#   "gulliver's travels",
#   'no place like home',
#   'travels with charley: in search of america',
#   'how to enjoy your life and your job'],
#  ...}

# %%
recommendations = {str(k): v for k, v in recommendations.items()}
with open('../results/content_based_filtering_recommendations.pkl', 'wb') as f:
    pickle.dump(recommendations, f)

# %%
masked_books = pd.read_csv("../datasets/test_edges.csv")

# %%
# quick sanity check eval
user_precisions = []
user_recalls = []
total_hits = 0
total_users = 0
total_relevant = 0

for user_id, recommended_books in recommendations.items():

    if int(user_id) not in masked_books['User-ID'].values:
        continue
    
    user_masked_books = masked_books[masked_books['User-ID'] == int(user_id)]
    relevant_books = {row['join_title'] for _, row in user_masked_books.iterrows() if row['Book-Rating'] > 7}
    
    if len(relevant_books) == 0:
        continue
    
    # count how many recommended books are relevant
    user_hits = len(set(recommended_books) & relevant_books)
    total_hits += user_hits
    total_users += 1
    total_relevant += len(relevant_books)
    
    # calculate per-user metrics
    user_precision = user_hits / 20
    user_recall = user_hits / len(relevant_books)
    
    user_precisions.append(user_precision)
    user_recalls.append(user_recall)

# Calculate overall averages
avg_precision = sum(user_precisions) / len(user_precisions) if user_precisions else 0
avg_recall = sum(user_recalls) / len(user_recalls) if user_recalls else 0

print(f"\n=== Overall Results ===")
print(f"Average Precision@20: {avg_precision:.4f}")
print(f"Average Recall@20: {avg_recall:.4f}")
print(f"Total hits: {total_hits}")
print(f"Total users evaluated: {total_users}")
print(f"Total relevant books: {total_relevant}")
# Out:
# === Overall Results ===
# Average Precision@20: 0.0097
# Average Recall@20: 0.0886
# Total hits: 548
# Total users evaluated: 2819
# Total relevant books: 6231
